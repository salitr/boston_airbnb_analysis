# %% [markdown]
# # <center> Boston Airbnb Analysis
#
# <img src="https://cdn-images-1.medium.com/max/2400/1*BfcMRSGnD5pMG61KfPqjVA.png" style="width:900px;"/>
#
# Original photo by [Anthony Delanoix](https://unsplash.com/@anthonydelanoix) on [Unsplash](https://unsplash.com)

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
cd = os.getcwd()
import re
import statsmodels.api as sm

# magic word for producing visualizations in notebook
# %matplotlib inline

import plotly.plotly as py #for creating interactive data visualizations
import plotly.graph_objs as go
from plotly import tools
import plotly.tools as tls
py.sign_in('salitr', '0Vm0IzVDJl70ydZG9ZjW') #API key has been removed for security
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot #to work with data visualization offline
init_notebook_mode(connected=True)
import cufflinks as cf #connects Plotly with pandas to produce the interactive data visualizations
cf.go_offline()

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import metrics

from IPython.display import Image

import gmaps
gmaps.configure(api_key='AIzaSyDVKBGsT0nQS_2V7KwS8DfSko2CVIQWjQU') #API key has been removed for security
from ipywidgets.embed import embed_minimal_html
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ---
# # <center>STAGE ONE</center>
# ---

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# ### 1.1 Business Questions
#
# <font color=blue>
#     Q1. How prices for all Boston's Airbnb fluctuate throughout the year 2019?
#
# <font color=blue>
#     Q2. What are the peak and off-peak times during the year for Airbnb rental prices in Boston?
#
# <font color=blue>
#     Q3. Who are the hosts with the most number of Airbnb listings?
#
# <font color=blue>
#     Q4. Which neighborhoods have the most number of listing in Boston?
#
# <font color=blue>
#     Q5. Which are the most expensive neighborhoods in Boston?
#
# <font color=blue>
#     Q6. Which are the popular neighborhoods based on the average number of reviews?
#
# <font color=blue>
#     Q7. Which type of room has the majority of listings in Boston Airbnb?
#
# <font color=blue>
#     Q8. What are the features that influence the price in Boston Airbnb? Moreover, can we predict the rental price of new listings based on a predictive model?

# %% [markdown]
# ## 2. Data Understanding

# %%
#loading the three datasets
listings = pd.read_csv(cd+'/listings.csv')
reviews = pd.read_csv(cd+'/reviews.csv')
calendar = pd.read_csv(cd+'/calendar.csv')

# %% [markdown]
# ### 2.1 listings data

# %%
#displaying the dataset
print(listings.shape)
listings.sample(10)
# Out:
# (6155, 106)
#             id                            listing_url     scrape_id  \
# 963    7825327   https://www.airbnb.com/rooms/7825327  2.019020e+13
# 602    5048406   https://www.airbnb.com/rooms/5048406  2.019020e+13
# 5978  31341983  https://www.airbnb.com/rooms/31341983  2.019020e+13
# 3930  23090526  https://www.airbnb.com/rooms/23090526  2.019020e+13
# 227    1494726   https://www.airbnb.com/rooms/1494726  2.019020e+13
# 4538  25416313  https://www.airbnb.com/rooms/25416313  2.019020e+13
# 696    5927267   https://www.airbnb.com/rooms/5927267  2.019020e+13
# 4812  27125054  https://www.airbnb.com/rooms/27125054  2.019020e+13
# 1696  13652374  https://www.airbnb.com/rooms/13652374  2.019020e+13
# 3258  21076367  https://www.airbnb.com/rooms/21076367  2.019020e+13
#
#      last_scraped                                               name  \
# 963        2/9/19                Historical South End Brownstone T-4
# 602        2/9/19                  3rd floor room in Victorian House
# 5978       2/9/19                   Boston市区Boston College附近地铁沿线优质房源
# 3930       2/9/19          Great 2 bedrooms near Airport East Boston
# 227        2/9/19                                    Cozy in Rozzie!
# 4538       2/9/19    Newly renovated, Best Location CENTER of Boston
# 696        2/9/19                  Large room, wood floor, 2 windows
# 4812       2/9/19  Cute & Spacious Home in the Heart of Local Boston
# 1696       2/9/19              Private Room near Forest Hills T Stop
# 3258       2/9/19   Charming 1 Bedroom in Beacon Hill (Downtown BOS)
#
#                                                 summary  \
# 963   Flash Sale For this Month Only Stays Up To 40%...
# 602   Huge 8 rooms, 5 bdrms.  house. Kitchen, living...
# 5978  交通极其便利,出门1mins到地铁C线,4mins到地铁D线,5mins到地铁B线,步行15...
# 3930  This two cozy and comfortable bedroom apartmen...
# 227   Spacious & quiet room w. private bath, for 1+ ...
# 4538  1 bedroom 1 and half bathrooms available in a ...
# 696   It is a great location and room is very nice t...
# 4812  This is an entire one-floor single home with a...
# 1696  Lugares de interés: Arnold Arboretum Walter St...
# 3258  A one bedroom apartment at the heart of Boston...
#
#                                                   space  \
# 963   *We offer you the most competitive rates.  Bef...
# 602   We offer full kitchen access: dishes, oven, co...
# 5978                                   可以使用卫生间厨房客厅等公用空间
# 3930  We have everything in this place, and the gues...
# 227   Spacious room with private bathroom in really ...
# 4538  Access to the Red Line Shawmut train station t...
# 696                                                 NaN
# 4812  This single ADA family home features lots of o...
# 1696  Private room in the beautiful neighborhood of ...
# 3258                                                NaN
#
#                                             description experiences_offered  \
# 963   Flash Sale For this Month Only Stays Up To 40%...                none
# 602   Huge 8 rooms, 5 bdrms.  house. Kitchen, living...                none
# 5978  交通极其便利,出门1mins到地铁C线,4mins到地铁D线,5mins到地铁B线,步行15...                none
# 3930  This two cozy and comfortable bedroom apartmen...                none
# 227   Spacious & quiet room w. private bath, for 1+ ...                none
# 4538  1 bedroom 1 and half bathrooms available in a ...                none
# 696   It is a great location and room is very nice t...                none
# 4812  This is an entire one-floor single home with a...                none
# 1696  Lugares de interés: Arnold Arboretum Walter St...                none
# 3258  A one bedroom apartment at the heart of Boston...                none
#
#                                   neighborhood_overview  ... instant_bookable  \
# 963   One of the trendiest neighborhoods in Boston, ...  ...                t
# 602   Dorchester is the largest and oldest residenti...  ...                f
# 5978                 靠近Boston College和Boston University  ...                f
# 3930  A very nice, quiet, and safe neighborhood. The...  ...                t
# 227   If you like quaint villages, come to Rozzie Sq...  ...                f
# 4538  I've lived here for over 15 years, it is consi...  ...                f
# 696                                                 NaN  ...                t
# 4812  Dorchester is Boston's largest neighborhood wi...  ...                f
# 1696                                                NaN  ...                f
# 3258                                                NaN  ...                f
#
#      is_business_travel_ready          cancellation_policy  \
# 963                         f  strict_14_with_grace_period
# 602                         f  strict_14_with_grace_period
# 5978                        f  strict_14_with_grace_period
# 3930                        f                     moderate
# 227                         f  strict_14_with_grace_period
# 4538                        f                     moderate
# 696                         f                     moderate
# 4812                        f                     moderate
# 1696                        f                     flexible
# 3258                        f  strict_14_with_grace_period
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 963                              f                                f
# 602                              f                                f
# 5978                             f                                f
# 3930                             f                                f
# 227                              f                                f
# 4538                             f                                f
# 696                              f                                f
# 4812                             f                                f
# 1696                             f                                f
# 3258                             f                                f
#
#       calculated_host_listings_count  \
# 963                               12
# 602                                2
# 5978                               1
# 3930                               2
# 227                                1
# 4538                               7
# 696                                4
# 4812                               1
# 1696                               1
# 3258                               1
#
#       calculated_host_listings_count_entire_homes  \
# 963                                            12
# 602                                             0
# 5978                                            0
# 3930                                            2
# 227                                             0
# 4538                                            1
# 696                                             0
# 4812                                            1
# 1696                                            0
# 3258                                            1
#
#      calculated_host_listings_count_private_rooms  \
# 963                                             0
# 602                                             2
# 5978                                            1
# 3930                                            0
# 227                                             1
# 4538                                            6
# 696                                             4
# 4812                                            0
# 1696                                            1
# 3258                                            0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 963                                             0               0.52
# 602                                             0               0.57
# 5978                                            0                NaN
# 3930                                            0               0.91
# 227                                             0               0.26
# 4538                                            0               0.40
# 696                                             0               2.05
# 4812                                            0                NaN
# 1696                                            0                NaN
# 3258                                            0               0.12
#
# [10 rows x 106 columns]

# %%
#summary of each feature
listings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  6.155000e+03  6.155000e+03            0.0         0.0             0.0
# mean   1.879144e+07  2.019020e+13            NaN         NaN             NaN
# std    8.802758e+06  0.000000e+00            NaN         NaN             NaN
# min    3.781000e+03  2.019020e+13            NaN         NaN             NaN
# 25%    1.278680e+07  2.019020e+13            NaN         NaN             NaN
# 50%    2.043183e+07  2.019020e+13            NaN         NaN             NaN
# 75%    2.601302e+07  2.019020e+13            NaN         NaN             NaN
# max    3.224338e+07  2.019020e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  6.155000e+03                   0.0          6153.000000
# mean   5.998043e+07                   NaN           152.358524
# std    6.481161e+07                   NaN           372.054375
# min    4.804000e+03                   NaN             0.000000
# 25%    1.180787e+07                   NaN             1.000000
# 50%    3.028359e+07                   NaN             4.000000
# 75%    9.545940e+07                   NaN            38.000000
# max    2.418780e+08                   NaN          1480.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed  ...  \
# count                6153.000000                           0.0  ...
# mean                  152.358524                           NaN  ...
# std                   372.054375                           NaN  ...
# min                     0.000000                           NaN  ...
# 25%                     1.000000                           NaN  ...
# 50%                     4.000000                           NaN  ...
# 75%                    38.000000                           NaN  ...
# max                  1480.000000                           NaN  ...
#
#        review_scores_communication  review_scores_location  \
# count                  4854.000000             4849.000000
# mean                      9.681706                9.545886
# std                       0.807092                0.777950
# min                       2.000000                2.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  license  jurisdiction_names  \
# count          4849.000000      0.0                 0.0
# mean              9.300474      NaN                 NaN
# std               0.891518      NaN                 NaN
# min               2.000000      NaN                 NaN
# 25%               9.000000      NaN                 NaN
# 50%               9.000000      NaN                 NaN
# 75%              10.000000      NaN                 NaN
# max              10.000000      NaN                 NaN
#
#        calculated_host_listings_count  \
# count                     6155.000000
# mean                        35.479285
# std                         73.147833
# min                          1.000000
# 25%                          1.000000
# 50%                          3.000000
# 75%                         30.000000
# max                        306.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  6155.000000
# mean                                     33.577417
# std                                      73.626063
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                      21.000000
# max                                     306.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   6155.000000
# mean                                       1.840780
# std                                        4.079204
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       30.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  6155.000000        4911.000000
# mean                                      0.061089           1.976685
# std                                       0.540380           2.100526
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.380000
# 50%                                       0.000000           1.190000
# 75%                                       0.000000           3.000000
# max                                       8.000000          13.710000
#
# [8 rows x 46 columns]

# %%
#listing all the features
list(listings.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
#checking the nulls for each feature
print(listings.isnull().sum().any())
listings.isnull().sum().sort_values(ascending=False)
# Out:
# True
# xl_picture_url                                  6155
# neighbourhood_group_cleansed                    6155
# host_acceptance_rate                            6155
# jurisdiction_names                              6155
# license                                         6155
# medium_url                                      6155
# thumbnail_url                                   6155
# square_feet                                     6057
# weekly_price                                    5628
# monthly_price                                   5626
# access                                          2463
# notes                                           2445
# interaction                                     2064
# host_about                                      2025
# house_rules                                     1974
# neighborhood_overview                           1952
# security_deposit                                1875
# transit                                         1790
# space                                           1401
# review_scores_checkin                           1306
# review_scores_location                          1306
# review_scores_value                             1306
# review_scores_accuracy                          1304
# review_scores_cleanliness                       1302
# review_scores_communication                     1301
# review_scores_rating                            1299
# reviews_per_month                               1244
# last_review                                     1244
# first_review                                    1244
# host_response_time                              1238
#                                                 ...
# instant_bookable                                   0
# is_business_travel_ready                           0
# cancellation_policy                                0
# require_guest_profile_picture                      0
# require_guest_phone_verification                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calendar_updated                                   0
# minimum_nights_avg_ntm                             0
# country_code                                       0
# maximum_maximum_nights                             0
# country                                            0
# latitude                                           0
# longitude                                          0
# is_location_exact                                  0
# property_type                                      0
# calculated_host_listings_count_shared_rooms        0
# accommodates                                       0
# bed_type                                           0
# amenities                                          0
# price                                              0
# guests_included                                    0
# extra_people                                       0
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# id                                                 0
# Length: 106, dtype: int64

# %% [markdown]
# As the result of the above cell reports, many of the listings dataset's features have missing values. In fact, some of them has no entry at all. An issue that has to be addressed.

# %%
#checking the number of duplicates
listings.duplicated().sum()
# Out:
# 0

# %%
#checking the number of unique values for each feature
listings.nunique().sort_values()
# Out:
# neighbourhood_group_cleansed                      0
# xl_picture_url                                    0
# medium_url                                        0
# thumbnail_url                                     0
# license                                           0
# jurisdiction_names                                0
# host_acceptance_rate                              0
# state                                             1
# has_availability                                  1
# country_code                                      1
# scrape_id                                         1
# requires_license                                  1
# calendar_last_scraped                             1
# last_scraped                                      1
# is_business_travel_ready                          1
# country                                           1
# experiences_offered                               1
# instant_bookable                                  2
# is_location_exact                                 2
# market                                            2
# require_guest_profile_picture                     2
# host_identity_verified                            2
# host_has_profile_pic                              2
# host_is_superhost                                 2
# require_guest_phone_verification                  2
# room_type                                         3
# host_response_time                                4
# bed_type                                          5
# calculated_host_listings_count_shared_rooms       6
# cancellation_policy                               6
#                                                ...
# host_location                                   236
# number_of_reviews                               300
# availability_365                                366
# price                                           398
# last_review                                     757
# reviews_per_month                               777
# first_review                                   1543
# host_name                                      1575
# host_about                                     1596
# host_since                                     1712
# notes                                          2232
# interaction                                    2353
# house_rules                                    2400
# access                                         2548
# neighborhood_overview                          2563
# transit                                        2757
# host_picture_url                               2778
# host_thumbnail_url                             2778
# host_id                                        2784
# host_url                                       2784
# space                                          3494
# summary                                        4888
# amenities                                      4980
# description                                    5311
# name                                           5901
# picture_url                                    6000
# longitude                                      6150
# latitude                                       6150
# listing_url                                    6155
# id                                             6155
# Length: 106, dtype: int64

# %%
#Providing a set of columns with 0 missing values.
listings_no_nulls = set(listings.columns[listings.isnull().mean()==0]) 
print(listings_no_nulls)
# Out:
# {'latitude', 'minimum_maximum_nights', 'id', 'calculated_host_listings_count_entire_homes', 'availability_30', 'minimum_nights_avg_ntm', 'extra_people', 'picture_url', 'maximum_nights', 'scrape_id', 'country', 'availability_365', 'availability_60', 'minimum_nights', 'maximum_maximum_nights', 'listing_url', 'calculated_host_listings_count', 'maximum_minimum_nights', 'host_id', 'street', 'accommodates', 'requires_license', 'guests_included', 'number_of_reviews', 'longitude', 'host_url', 'experiences_offered', 'bed_type', 'availability_90', 'number_of_reviews_ltm', 'host_verifications', 'amenities', 'require_guest_phone_verification', 'country_code', 'require_guest_profile_picture', 'is_location_exact', 'has_availability', 'calendar_updated', 'maximum_nights_avg_ntm', 'is_business_travel_ready', 'cancellation_policy', 'property_type', 'neighbourhood_cleansed', 'instant_bookable', 'calendar_last_scraped', 'minimum_minimum_nights', 'last_scraped', 'price', 'room_type', 'smart_location', 'calculated_host_listings_count_shared_rooms', 'calculated_host_listings_count_private_rooms'}

# %%
#Providing a set of columns with more than 75% of the values missing
listings_most_nulls = set(listings.columns[listings.isnull().mean()> 0.75]) 
print(listings_most_nulls)
# Out:
# {'xl_picture_url', 'square_feet', 'weekly_price', 'jurisdiction_names', 'thumbnail_url', 'license', 'monthly_price', 'neighbourhood_group_cleansed', 'host_acceptance_rate', 'medium_url'}

# %% [markdown]
# Based on the previous data exploration, the next cell will set only the features that would be useful for our analysis. The features **'xl_picture_url', 'square_feet', 'weekly_price', 'jurisdiction_names', 'thumbnail_url', 'license', 'monthly_price', 'neighbourhood_group_cleansed', 'host_acceptance_rate', and 'medium_url'** were dropped because more than 75% of the values are missing.

# %%
#setting the chosen 20 features for the analysis
listings_columns = ['id', 'host_name', 'host_response_rate', 
               'host_is_superhost', 'neighbourhood_cleansed',
               'zipcode', 'property_type', 'room_type',
               'accommodates', 'bathrooms', 'bedrooms',
               'beds', 'amenities', 'price', 'cleaning_fee',
               'number_of_reviews', 'review_scores_rating', 'instant_bookable',
               'cancellation_policy', 'reviews_per_month', 'latitude', 'longitude']

# %%
#confirming the final dataset has only the chosen 22 features
df_listings = listings[listings_columns]
print(df_listings.shape)
df_listings.sample(10)
# Out:
# (6155, 22)
#             id host_name host_response_rate host_is_superhost  \
# 1057   8381472      Nick                NaN                 f
# 5166  28586005     Domio               100%                 f
# 5997  31397068     Steve                94%                 f
# 291    2021483   Shannon               100%                 t
# 1227   9853959  Margaret                NaN                 f
# 4908  27549840      Sean               100%                 f
# 5674  30180140      Evon                98%                 f
# 4964  27733061      Aziz               100%                 t
# 3991  23272168  Bluebird                76%                 f
# 103     377474   Hermina               100%                 f
#
#      neighbourhood_cleansed zipcode property_type        room_type  \
# 1057              South End    2118     Apartment  Entire home/apt
# 5166              North End    2113     Apartment  Entire home/apt
# 5997          Jamaica Plain    2130     Apartment  Entire home/apt
# 291            South Boston    2127   Condominium  Entire home/apt
# 1227              South End    2118     Apartment  Entire home/apt
# 4908              North End    2109     Apartment  Entire home/apt
# 5674               Downtown    2116     Apartment  Entire home/apt
# 4964               Back Bay    2116     Apartment     Private room
# 3991           South Boston    2127     Apartment  Entire home/apt
# 103              Dorchester    2122         House  Entire home/apt
#
#       accommodates  bathrooms  ...  \
# 1057             4        2.0  ...
# 5166             6        1.0  ...
# 5997             8        1.0  ...
# 291              6        2.0  ...
# 1227             4        1.0  ...
# 4908             3        1.0  ...
# 5674             4        1.0  ...
# 4964             2        1.0  ...
# 3991             5        2.0  ...
# 103             10        1.5  ...
#
#                                               amenities     price  \
# 1057  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $400.00
# 5166  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $129.00
# 5997  {Wifi,"Air conditioning",Kitchen,Heating,"Smok...  $300.00
# 291   {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $500.00
# 1227  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $195.00
# 4908  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...  $160.00
# 5674  {TV,Wifi,"Air conditioning",Kitchen,Breakfast,...  $149.00
# 4964  {TV,Wifi,"Air conditioning",Kitchen,Breakfast,...  $125.00
# 3991  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $279.00
# 103   {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $495.00
#
#      cleaning_fee number_of_reviews review_scores_rating  instant_bookable  \
# 1057          NaN                 0                  NaN                 f
# 5166     $120.00                 13                 97.0                 f
# 5997     $165.00                  1                100.0                 t
# 291      $100.00                  5                 96.0                 f
# 1227      $25.00                  0                  NaN                 f
# 4908          NaN                 6                 96.0                 t
# 5674      $69.00                 15                 95.0                 t
# 4964      $50.00                 38                 97.0                 t
# 3991     $100.00                  1                100.0                 t
# 103      $150.00                 22                 87.0                 f
#
#               cancellation_policy reviews_per_month   latitude  longitude
# 1057                     flexible               NaN  42.343095 -71.079798
# 5166  strict_14_with_grace_period              3.28  42.365550 -71.056143
# 5997  strict_14_with_grace_period              1.00  42.321790 -71.109635
# 291   strict_14_with_grace_period              0.16  42.335352 -71.047413
# 1227  strict_14_with_grace_period               NaN  42.341212 -71.079551
# 4908                     flexible              1.01  42.365607 -71.053421
# 5674                     flexible              5.77  42.352685 -71.063872
# 4964                     moderate              7.08  42.350248 -71.085469
# 3991  strict_14_with_grace_period              1.00  42.336815 -71.036718
# 103   strict_14_with_grace_period              0.28  42.298390 -71.059312
#
# [10 rows x 22 columns]

# %%
#investgating the data type for each feature
df_listings.dtypes
# Out:
# id                          int64
# host_name                  object
# host_response_rate         object
# host_is_superhost          object
# neighbourhood_cleansed     object
# zipcode                    object
# property_type              object
# room_type                  object
# accommodates                int64
# bathrooms                 float64
# bedrooms                  float64
# beds                      float64
# amenities                  object
# price                      object
# cleaning_fee               object
# number_of_reviews           int64
# review_scores_rating      float64
# instant_bookable           object
# cancellation_policy        object
# reviews_per_month         float64
# latitude                  float64
# longitude                 float64
# dtype: object

# %% [markdown]
# Some of the final features need to be converted to the correct data type, which will be addressed later.

# %%
#checking the number of nulls for each chosen feature
print(df_listings.isnull().sum().any())
df_listings.isnull().sum().sort_values(ascending=False)
# Out:
# True
# review_scores_rating      1299
# reviews_per_month         1244
# host_response_rate        1238
# cleaning_fee               979
# zipcode                     42
# bedrooms                     6
# bathrooms                    5
# beds                         3
# host_name                    2
# host_is_superhost            2
# room_type                    0
# neighbourhood_cleansed       0
# property_type                0
# longitude                    0
# accommodates                 0
# latitude                     0
# amenities                    0
# price                        0
# number_of_reviews            0
# instant_bookable             0
# cancellation_policy          0
# id                           0
# dtype: int64

# %% [markdown]
# Again, some of the features have missing values. A further investigation will be applied to decide if we need to either remove or impute the rows.

# %%
#checking the number of unique values for each chosen feature
df_listings.nunique().sort_values()
# Out:
# instant_bookable             2
# host_is_superhost            2
# room_type                    3
# cancellation_policy          6
# bedrooms                     9
# bathrooms                   12
# accommodates                16
# beds                        16
# property_type               21
# neighbourhood_cleansed      25
# zipcode                     41
# host_response_rate          43
# review_scores_rating        45
# cleaning_fee               148
# number_of_reviews          300
# price                      398
# reviews_per_month          777
# host_name                 1575
# amenities                 4980
# longitude                 6150
# latitude                  6150
# id                        6155
# dtype: int64

# %% [markdown]
# #### 2.1.1 Quality Issues
#
# - Missing data in some of the final 22 chosen features
# - Erroneous datatypes in prices and dates features
# - Source types in amenities where fields intricate with symbols
#
#
# #### 2.1.2 Tidiness Issues
# - Features with more than one representation: room_type, amenities, and neighbourhood_cleansed.

# %% [markdown]
# ### 2.2 reviews data

# %%
#displaying the dataset
print(reviews.shape)
reviews.sample(10)
# Out:
# (199330, 6)
#         listing_id         id        date  reviewer_id   reviewer_name  \
# 121665    15582062  209963762  2017-11-06      7078806            Lori
# 98580     13296735  104962035  2016-09-29     56434819        Marianne
# 69803      7692933   95225584  2016-08-18      2157137            Alis
# 174463    22327139  258125311  2018-04-28    182377265           Chris
# 114202    15044173  340020707  2018-10-22    218638155          Joshua
# 13277       815639  209572469  2017-11-05    113911928         Heather
# 111627    14868157  332523712  2018-10-05     93661842            Gill
# 199318    31690021  409724312  2019-02-08     67259979         Yerzhan
# 107846    14483758  151604995  2017-05-13     21468084           Bryan
# 178609    23170412  248438357  2018-03-31      2441749  Eric And Susan
#
#                                                  comments
# 121665  If you know Boston Back Bay, you'll really app...
# 98580   Ron and Ignacio are adorable hosts, they did t...
# 69803   Had a very serene and comfortable stay at Phyl...
# 174463  All and all this is a must stay if your visiti...
# 114202  This apartment rocks. It is a beautiful space,...
# 13277   This place was perfect. It's in a great locati...
# 111627  Lori is a great host ...I enjoyed chatting wit...
# 199318  It’s perfect place to stay. Very clean and nic...
# 107846  Matthew is a responsive host and the apartment...
# 178609  Such a cool 1 br apartment, and the location w...

# %%
#summary of each column
reviews.describe()
# Out:
#          listing_id            id   reviewer_id
# count  1.993300e+05  1.993300e+05  1.993300e+05
# mean   1.258614e+07  2.083162e+08  7.268836e+07
# std    8.224075e+06  1.076633e+08  6.192693e+07
# min    3.781000e+03  1.021000e+03  1.000000e+00
# 25%    4.924009e+06  1.154105e+08  2.073139e+07
# 50%    1.339342e+07  2.135150e+08  5.409988e+07
# 75%    1.930943e+07  3.024042e+08  1.167099e+08
# max    3.216361e+07  4.097567e+08  2.414605e+08

# %%
#information about each feature
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199330 entries, 0 to 199329
# Data columns (total 6 columns):
# listing_id       199330 non-null int64
# id               199330 non-null int64
# date             199330 non-null object
# reviewer_id      199330 non-null int64
# reviewer_name    199330 non-null object
# comments         199242 non-null object
# dtypes: int64(3), object(3)
# memory usage: 9.1+ MB

# %%
#checking the number of nulls for each column
print(reviews.isnull().sum().any())
reviews.isnull().sum().sort_values(ascending=False)
# Out:
# True
# comments         88
# reviewer_name     0
# reviewer_id       0
# date              0
# id                0
# listing_id        0
# dtype: int64

# %% [markdown]
# #### 2.2.1 Quality Issues
#
# - Missing data in comments
# - Erroneous datatypes in ids and dates
# - Source types in comments reviewer_name where some fields intricate with symbols and some are written in different languages.

# %% [markdown]
# ### 2.3 calendar data

# %%
#displaying the dataset
print(calendar.shape)
calendar.sample(10)
# Out:
# (2246575, 7)
#          listing_id        date available    price adjusted_price  \
# 816327     16030858  2019-08-09         f   $45.00         $45.00
# 1744053    26453232  2019-07-09         t  $150.00        $150.00
# 1670522    25871107  2019-11-07         f  $283.00        $283.00
# 383168      8336364  2019-10-17         f  $100.00        $100.00
# 1879390    28546173  2019-09-21         t  $533.00        $533.00
# 100768       916123  2019-11-01         t  $199.00        $199.00
# 695254     14950476  2019-03-02         f  $307.00        $307.00
# 1967017    29379824  2019-04-19         f   $50.00         $50.00
# 1891809    28386218  2019-07-16         f   $60.00         $60.00
# 2176426    30153933  2019-10-31         f  $135.00        $135.00
#
#          minimum_nights  maximum_nights
# 816327                3             365
# 1744053              32            1125
# 1670522               3            1125
# 383168                2            1125
# 1879390               3            1125
# 100768                1            1125
# 695254                2            1125
# 1967017               2               7
# 1891809               2            1125
# 2176426               1            1125

# %%
#summary of each column
calendar.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  2.246575e+06    2.246575e+06    2.246575e+06
# mean   1.879144e+07    6.885056e+00    1.698545e+04
# std    8.802044e+06    4.036776e+01    1.274523e+06
# min    3.781000e+03    1.000000e+00    1.000000e+00
# 25%    1.278406e+07    1.000000e+00    1.050000e+02
# 50%    2.043183e+07    2.000000e+00    1.125000e+03
# 75%    2.601346e+07    3.000000e+00    1.125000e+03
# max    3.224338e+07    9.990000e+02    1.000000e+08

# %%
#checking the number of nulls for each column
print(calendar.isnull().sum().any())
calendar.isnull().sum().sort_values(ascending=False)
# Out:
# False
# maximum_nights    0
# minimum_nights    0
# adjusted_price    0
# price             0
# available         0
# date              0
# listing_id        0
# dtype: int64

# %%
#information about each feature
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2246575 entries, 0 to 2246574
# Data columns (total 7 columns):
# listing_id        int64
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights    int64
# maximum_nights    int64
# dtypes: int64(3), object(4)
# memory usage: 120.0+ MB

# %% [markdown]
# #### 2.3.1 Quality Issues
#
# - Erroneous datatypes in price and data

# %% [markdown]
# ---
# ### <font color=blue> Q1. How prices for all Boston's airbnb fluctuate throughout the year 2019?

# %%
calendar_clean = calendar.copy()

# %%
#removing the $ sign for price, and converting the date's type to datetime
calendar_clean['year'], calendar_clean['month'], calendar_clean['day'] = calendar_clean['date'].str.split('-',2).str
calendar_clean.date = pd.to_datetime(calendar_clean['date'])
calendar_clean.price = calendar_clean.price.str.replace(',','')
calendar_clean.price = calendar_clean.price.str.replace('$','')
calendar_clean[['price']] = calendar_clean[['price']].astype(float)

#removing the columns that will not be used for this question
calendar_clean = calendar_clean.drop(['available', 'adjusted_price', 'minimum_nights', 'maximum_nights'], axis=1)

# %%
#checking the quality of the dataframe
calendar_clean.sample(5)
# Out:
#          listing_id       date  price  year month day
# 1448601    23170412 2019-10-22  283.0  2019    10  22
# 1448961    23272728 2019-12-20   99.0  2019    12  20
# 2144385    31102316 2020-01-08  131.0  2020    01  08
# 11022       1183032 2020-01-08  175.0  2020    01  08
# 1647863    25126538 2019-06-21  525.0  2019    06  21

# %%
#grouping the listings by date and then finding the average price per day
prices = pd.DataFrame(calendar_clean.groupby(['date']).mean()['price']).reset_index()
prices
# Out:
#          date       price
# 0  2019-02-01  143.140812
# 1  2019-03-01  177.284107
# 2  2019-04-01  208.852136
# 3  2019-05-01  235.687540
# 4  2019-06-01  229.730376
# 5  2019-07-01  237.662488
# 6  2019-08-01  234.053924
# 7  2019-09-01  232.110815
# 8  2019-10-01  232.060769
# 9  2019-11-01  203.867051
# 10 2019-12-01  190.854999
# 11 2020-01-01  226.081858
# 12 2020-02-01  232.916714

# %%
#finding the average of the average daily prices
prices.price.mean()
# Out:
# 215.08826725126008

# %%
trace1 = go.Scatter(x=prices.date, y=prices.price, line = dict(color = '#7F7F7F'))

data = [trace1]


layout = {
    'title': 'Daily Average Price Change (Use the slider for more detailed trends)',
    'xaxis': {'title': 'Day'},
    'yaxis': {'title': 'Average Price ($)'},
               
    'shapes': [
        # Line Horizontal, average
        {
            'type': 'line',
            'x0': '2019-02-09',
            'y0': 215,
            'x1': '2020-02-08',
            'y1': 215,
            'line': {
                'color': 'black',
                'width': 1,
                'dash': 'dashdot',
            }
        },
        
        # 1st highlight during Apr 9 - Apr 21
        {
            'type': 'rect',
            # x-reference is assigned to the x-values
            'xref': 'x',
            # y-reference is assigned to the plot [0,1]
            'yref': 'paper',
            'x0': '2019-04-09',
            'y0': 0,
            'x1': '2019-04-21',
            'y1': 1,
            'fillcolor': '#d3d3d3',
            'opacity': 0.3,
            'line': {
                'width': 0,
            }
        },
        
        # 3nd highlight during Dec 25 - Feb 7
        {
            'type': 'rect',
            'xref': 'x',
            'yref': 'paper',
            'x0': '2019-12-25',
            'y0': 0,
            'x1': '2020-02-07',
            'y1': 1,
            'fillcolor': '#d3d3d3',
            'opacity': 0.3,
            'line': {
                'width': 0,
            }
        }
    ]
}

layout.update(dict(
    annotations=[go.Annotation(text="Overall Average Price ($215)", x='2019-03-15', y=215)]),
             xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(count=1,
                    label='YTD',
                    step='year',
                    stepmode='todate'),
                dict(count=1,
                    label='1y',
                    step='year',
                    stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
             )
              

py.iplot({'data': data, 'layout': layout}, filename='Daily Average Price Change')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:144: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
#
#
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/490.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The time series plot illustrates that we have two periods where the Airbnb listings prices increased promptly. The shaded areas show the dates when the price rises. The horizontal line represents the average renting price all year.
#
#     1. The period between April 8, 2019, and April 21, 2019, shows an increase in average prices above the overall average price. After further investigation, the increase is due to the Boston Marathon, one of the world's oldest and most challenging races. The marathon took place on Monday, April 15.
#
#     2. The period between December 25, 2019, and February 7, 2020, shows an increase in prices, which is expected as it holds the Christmas Day and the New Year's Eve and Day.
#
#     3. A significant difference in the average prices between February 2019 and February 2020. While in 2019 it was the lowest period with rates ranges between around $136 per night up to $200 per night, it starts from $234 per night in 2020.
#
#     4. Overall, the off-peak period for Boston's Airbnb occurs during the months of February and March in 2019, and the peak period occurs between April and October in 2019. Prices go down in November until the trend goes up again in December.

# %% [markdown]
# ---
# ### <font color=blue> Q2. What are the peak and off-peak months during the year for airbnb rental prices in Boston?

# %%
#splitting the date to year and month, then concat the files to create monthly column
calendar_clean['month'] = calendar_clean['year'].map(str) + "-" + calendar_clean['month'].map(str)

#convertting the month to date
calendar_clean.date = pd.to_datetime(calendar_clean['month'])

# %%
month_trend = calendar_clean.groupby('month').describe()['price'].reset_index()
month_trend = month_trend.drop(['count', 'std', '25%', '50%', '75%'], axis=1)
month_trend
# Out:
#       month        mean   min     max
# 0   2019-02  143.140812  10.0  5000.0
# 1   2019-03  177.284107  10.0  7132.0
# 2   2019-04  208.852136  10.0  5000.0
# 3   2019-05  235.687540  10.0  9999.0
# 4   2019-06  229.730376  10.0  5000.0
# 5   2019-07  237.662488  10.0  5000.0
# 6   2019-08  234.053924  10.0  5000.0
# 7   2019-09  232.110815  10.0  6414.0
# 8   2019-10  232.060769  10.0  5407.0
# 9   2019-11  203.867051  10.0  5000.0
# 10  2019-12  190.854999  10.0  5000.0
# 11  2020-01  226.081858  10.0  5000.0
# 12  2020-02  232.916714  10.0  5369.0

# %%
trace_mean = go.Scatter(
    x=month_trend.month,
    y=month_trend['mean'],
    name = "Average Price Per month",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

data = [trace_mean]

layout = {
    'title': 'Monthly Price Trend',
    'xaxis': {'title': 'Month'},
    'yaxis': {'title': 'Average Price ($)'},
               
    'shapes': [
        # Line Horizontal, average
        {
            'type': 'line',
            'x0': '2019-02-01',
            'y0': 215,
            'x1': '2020-02-01',
            'y1': 215,
            'line': {
                'color': 'black',
                'width': 1,
                'dash': 'dashdot',
            }
        },
        
        # 1st highlight above average months
        {
            'type': 'rect',
            # x-reference is assigned to the x-values
            'xref': 'x',
            # y-reference is assigned to the plot [0,1]
            'yref': 'y',
            'x0': '2019-02',
            'y0': 215,
            'x1': '2020-02',
            'y1': 240,
            'fillcolor': 'tomato',
            'opacity': 0.1,
            'line': {
                'width': 0,
            }
        },
        
        # 3nd highlight below average months
        {
            'type': 'rect',
            'xref': 'x',
            'yref': 'y',
            'x0': '2019-02',
            'y0': 215,
            'x1': '2020-02',
            'y1': 140,
            'fillcolor': 'olive',
            'opacity': 0.1,
            'line': {
                'width': 0,
            }
        }
    ]
}

layout.update(dict(annotations=[go.Annotation(text="Overall Average Price ($215)", x='2019-03-15', y=215)]))
        
fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Monthly Price Trend")
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/488.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The monthly price trend plot shows that the peak and off-peak months for Boston Airbnb listings' prices. The red-colored areas show the months when the average price per night is above the overall average price for all listings per night, while the green-colored area represents the off-peak months when the average price per night is below the overall average rate for all listings per night.
#
#     1. February, March, the beginning of April, November, and most of December in 2019 are the off-peak months when prices are below $215 per nights.
#
#     2. The second half of April, May, July, August, September, the first half of October, end of December in 2019 along with January and February in 2010 are the peak months when prices are above $215 per night.

# %% [markdown]
# ---
# # <center>STAGE TWO</center>
# ---

# %% [markdown]
# ## 3. Data Preparation

# %%
#copying the latest dataset
df_listings_prep1 = df_listings.copy()

# %%
#dropping the features with many number of missing data
df_listings_prep1 = df_listings_prep1.drop(['review_scores_rating', 'host_response_rate', 'reviews_per_month'], axis=1)

# %% [markdown]
# Here, as we found earlier, the features **'review_scores_rating', 'reviews_per_month', and 'host_response_rate'** have more than 1200 missing values out of 6155. In my opnion, the columns are not associated with sensitive information that would impact our analysis. Therefore, instead of droping the listings with these missing values or imputing the numbers, I decided to drop the feature as they will not be used in answering the business question or creating the model.

# %%
#investgating the data type for each feature
df_listings_prep1.dtypes
# Out:
# id                          int64
# host_name                  object
# host_is_superhost          object
# neighbourhood_cleansed     object
# zipcode                    object
# property_type              object
# room_type                  object
# accommodates                int64
# bathrooms                 float64
# bedrooms                  float64
# beds                      float64
# amenities                  object
# price                      object
# cleaning_fee               object
# number_of_reviews           int64
# instant_bookable           object
# cancellation_policy        object
# latitude                  float64
# longitude                 float64
# dtype: object

# %%
#converting accommodates' type to float
df_listings_prep1.accommodates = df_listings_prep1.accommodates.astype(float)

#converting number_of_reviews' type to float
df_listings_prep1.number_of_reviews = df_listings_prep1.number_of_reviews.astype(float)

#confirming zipcodes are all set with 5 numbers
df_listings_prep1.zipcode = df_listings_prep1.zipcode.astype(str).str.zfill(5)

#removing the $ sign for price and cleaning_fee, then converting the types to float

df_listings_prep1.price = df_listings_prep1.price.str.replace('$','')
df_listings_prep1.price = df_listings_prep1.price.str.replace(',','')
df_listings_prep1.cleaning_fee = df_listings_prep1.cleaning_fee.str.replace('$','')
df_listings_prep1.cleaning_fee = df_listings_prep1.cleaning_fee.str.replace(',','')
df_listings_prep1[['price', 'cleaning_fee']] = df_listings_prep1[['price', 'cleaning_fee']].astype(float)

# %%
#assessing the number of each data type
df_listings_prep1.dtypes.value_counts()
# Out:
# object     9
# float64    9
# int64      1
# dtype: int64

# %%
#setting the numerical features
features_num = df_listings_prep1.select_dtypes(include=['float', 'int'])
features_num
# Out:
#             id  accommodates  bathrooms  bedrooms  beds  price  cleaning_fee  \
# 0         3781           2.0        1.0       1.0   1.0  125.0          75.0
# 1         5506           2.0        1.0       1.0   1.0  145.0          40.0
# 2         6695           4.0        1.0       1.0   2.0  169.0          70.0
# 3         6976           2.0        1.0       1.0   1.0   65.0           0.0
# 4         8789           2.0        1.0       1.0   1.0   99.0         250.0
# 5         8792           2.0        1.0       1.0   1.0  154.0         250.0
# 6         9765           2.0        1.0       NaN   1.0  229.0          75.0
# 7         9824           2.0        1.0       NaN   1.0  209.0           NaN
# 8         9827           2.0        1.0       1.0   1.0  389.0         150.0
# 9         9855           3.0        1.0       1.0   1.0  259.0         150.0
# 10        9857           4.0        1.0       2.0   2.0  342.0           NaN
# 11        9858           6.0        1.0       2.0   2.0  489.0           NaN
# 12        9859           2.0        1.0       1.0   1.0  179.0           NaN
# 13        9860           2.0        1.0       1.0   1.0  259.0           NaN
# 14        9870           2.0        1.0       1.0   1.0  279.0           NaN
# 15       10730           2.0        1.0       1.0   1.0  150.0         250.0
# 16       10811           3.0        1.0       0.0   2.0  179.0         100.0
# 17       10813           3.0        1.0       0.0   1.0  179.0         100.0
# 18       10986           2.0        1.0       0.0   1.0  115.0         145.0
# 19       13589           6.0        2.0       3.0   3.0  389.0           NaN
# 20       13592           4.0        1.5       2.0   2.0  359.0           NaN
# 21       18711           7.0        1.0       3.0   3.0  126.0         120.0
# 22       21891           4.0        1.0       2.0   2.0  289.0         200.0
# 23       22208           2.0        1.0       NaN   1.0  225.0           NaN
# 24       22354           1.0        NaN       1.0   1.0  148.0          21.0
# 25       23370           2.0        1.0       1.0   1.0  289.0         150.0
# 26       23668           2.0        1.0       1.0   1.0  249.0         150.0
# 27       24240           5.0        2.0       2.0   3.0  275.0           0.0
# 28       25142           4.0        NaN       2.0   2.0  399.0         150.0
# 29       25418           2.0        1.0       1.0   1.0  279.0         200.0
# ...        ...           ...        ...       ...   ...    ...           ...
# 6125  32116807           2.0        1.0       1.0   1.0  120.0          35.0
# 6126  32125673           2.0        1.0       1.0   1.0   60.0          15.0
# 6127  32127951           5.0        1.0       2.0   2.0  143.0          40.0
# 6128  32133411           3.0        1.5       1.0   2.0   70.0          25.0
# 6129  32133771           2.0        1.0       0.0   1.0  100.0          60.0
# 6130  32138377           4.0        1.5       3.0   3.0   65.0          20.0
# 6131  32141341           5.0        2.0       1.0   4.0  200.0          30.0
# 6132  32147828           2.0        1.0       1.0   1.0  125.0          40.0
# 6133  32155120           2.0        1.0       1.0   1.0   43.0           NaN
# 6134  32158419           4.0        1.0       2.0   3.0  160.0           NaN
# 6135  32161143           3.0        1.0       2.0   2.0  160.0           NaN
# 6136  32162031           2.0        1.0       1.0   1.0   45.0           0.0
# 6137  32163609           3.0        1.0       1.0   1.0  109.0          30.0
# 6138  32163985           4.0        1.0       2.0   2.0  199.0          25.0
# 6139  32168098           2.0        1.0       1.0   1.0   85.0           NaN
# 6140  32172713           1.0        1.0       1.0   1.0   60.0           NaN
# 6141  32180329           5.0        1.0       2.0   1.0  220.0           NaN
# 6142  32183321           2.0        1.0       1.0   1.0   59.0          25.0
# 6143  32188679           1.0        1.0       0.0   1.0   60.0           NaN
# 6144  32195225           4.0        1.5       2.0   1.0  200.0           NaN
# 6145  32196121           2.0        1.0       1.0   1.0   45.0           NaN
# 6146  32197096           4.0        1.0       1.0   2.0   75.0           NaN
# 6147  32202426           2.0        1.0       1.0   2.0   80.0           NaN
# 6148  32213220           3.0        1.0       0.0   2.0  110.0           NaN
# 6149  32223560           4.0        1.0       1.0   1.0  250.0           NaN
# 6150  32234660           6.0        1.0       1.0   3.0  125.0           NaN
# 6151  32238109           2.0        1.0       1.0   1.0   75.0           NaN
# 6152  32241248           4.0        1.0       1.0   2.0   80.0          25.0
# 6153  32242842           2.0        1.0       1.0   1.0   60.0          40.0
# 6154  32243378           3.0        1.0       1.0   1.0   66.0           8.0
#
#       number_of_reviews   latitude  longitude
# 0                  14.0  42.365241 -71.029361
# 1                  80.0  42.329808 -71.095595
# 2                  85.0  42.329941 -71.093505
# 3                  75.0  42.292438 -71.135765
# 4                  22.0  42.359187 -71.062651
# 5                  24.0  42.358497 -71.062011
# 6                   9.0  42.342594 -71.079421
# 7                  23.0  42.349496 -71.085954
# 8                   8.0  42.352149 -71.063301
# 9                   3.0  42.343371 -71.098708
# 10                 25.0  42.354290 -71.072772
# 11                  1.0  42.344471 -71.081786
# 12                  3.0  42.350260 -71.084718
# 13                 22.0  42.354115 -71.074414
# 14                  8.0  42.344227 -71.077878
# 15                 27.0  42.358403 -71.061850
# 16                  7.0  42.349730 -71.087924
# 17                  1.0  42.349613 -71.089038
# 18                  2.0  42.363520 -71.050754
# 19                 63.0  42.355263 -71.072793
# 20                 20.0  42.353763 -71.074239
# 21                 43.0  42.323286 -71.062103
# 22                 21.0  42.352179 -71.063160
# 23                  4.0  42.343210 -71.077760
# 24                293.0  42.344957 -71.074857
# 25                  5.0  42.346091 -71.078578
# 26                  0.0  42.363865 -71.068950
# 27                 82.0  42.363660 -71.050232
# 28                  9.0  42.344865 -71.102600
# 29                  4.0  42.364945 -71.067668
# ...                 ...        ...        ...
# 6125                0.0  42.321519 -71.110608
# 6126                0.0  42.362714 -71.131194
# 6127                0.0  42.373256 -71.032211
# 6128                0.0  42.326400 -71.092240
# 6129                0.0  42.359055 -71.052996
# 6130                0.0  42.354935 -71.165600
# 6131                0.0  42.325101 -71.105237
# 6132                0.0  42.365379 -71.069163
# 6133                0.0  42.288390 -71.050601
# 6134                0.0  42.331076 -71.110691
# 6135                0.0  42.360359 -71.066792
# 6136                0.0  42.287114 -71.092115
# 6137                1.0  42.361173 -71.070311
# 6138                0.0  42.327272 -71.080344
# 6139                0.0  42.319170 -71.105199
# 6140                0.0  42.330545 -71.101546
# 6141                0.0  42.345382 -71.079692
# 6142                0.0  42.350709 -71.134464
# 6143                0.0  42.352673 -71.129030
# 6144                0.0  42.332255 -71.030875
# 6145                0.0  42.346257 -71.140473
# 6146                0.0  42.300713 -71.084060
# 6147                0.0  42.355790 -71.110322
# 6148                0.0  42.346640 -71.103684
# 6149                0.0  42.359254 -71.053765
# 6150                0.0  42.262505 -71.151490
# 6151                0.0  42.318001 -71.053537
# 6152                0.0  42.349531 -71.082424
# 6153                0.0  42.351701 -71.065359
# 6154                0.0  42.340967 -71.134066
#
# [6155 rows x 10 columns]

# %%
#setting the categorical features
features_cat = df_listings_prep1.select_dtypes(include='object')
features_cat
# Out:
#       host_name host_is_superhost neighbourhood_cleansed zipcode  \
# 0         Frank                 t            East Boston   02128
# 1         Terry                 t                Roxbury   02119
# 2         Terry                 t                Roxbury   02119
# 3          Phil                 t             Roslindale   02131
# 4          Anne                 f               Downtown   02108
# 5          Anne                 f               Downtown   02108
# 6      Seamless                 f              South End   02118
# 7      Seamless                 f               Back Bay   02115
# 8      Seamless                 f               Downtown   02111
# 9      Seamless                 f                 Fenway   02215
# 10     Seamless                 f               Back Bay   02116
# 11     Seamless                 f               Back Bay   02116
# 12     Seamless                 f               Back Bay   02115
# 13     Seamless                 f               Back Bay   02116
# 14     Seamless                 f              South End   02116
# 15         Anne                 f               Downtown   02108
# 16     Michelle                 f               Back Bay   02115
# 17     Michelle                 f               Back Bay   02115
# 18     Michelle                 f              North End   02109
# 19     Seamless                 f               Back Bay   02116
# 20     Seamless                 f               Back Bay   02116
# 21        Lance                 f             Dorchester   02125
# 22     Seamless                 f               Downtown   02111
# 23     Seamless                 f              South End   02118
# 24       Robert                 f              South End   02116
# 25     Seamless                 f               Back Bay   02116
# 26     Seamless                 f               West End   02114
# 27     Gretchen                 t              North End   02109
# 28     Seamless                 f                 Fenway   02215
# 29     Seamless                 f               West End   02114
# ...         ...               ...                    ...     ...
# 6125    Cortney                 f          Jamaica Plain   02130
# 6126   Shekeyla                 f                Allston   02134
# 6127     Taylor                 f            East Boston   02128
# 6128      Wendy                 f                Roxbury   02119
# 6129      Paige                 f               Downtown   02109
# 6130     Rachel                 f               Brighton   02135
# 6131     Nicole                 f          Jamaica Plain   02130
# 6132     Thomas                 f               West End   02114
# 6133      Taryn                 f             Dorchester   02122
# 6134     Hesham                 f           Mission Hill   02130
# 6135  Ekaterina                 f            Beacon Hill   02114
# 6136   Mojisola                 f             Dorchester   02124
# 6137     Ashley                 f               West End   02114
# 6138   Stayhere                 f                Roxbury   02119
# 6139      David                 f          Jamaica Plain   02130
# 6140    Brigith                 f           Mission Hill   02120
# 6141       Lola                 f               Back Bay   02116
# 6142       Hank                 f                Allston   02134
# 6143     Yaling                 f                Allston   02134
# 6144    Dmitriy                 f           South Boston   02127
# 6145    Kashyap                 f               Brighton   02135
# 6146       Alan                 f             Dorchester   02121
# 6147    Barbara                 f                Allston   02139
# 6148     Taylor                 f                 Fenway   02215
# 6149       Jane                 f               Downtown   02109
# 6150     Daniel                 f           West Roxbury   02132
# 6151   Courtney                 f             Dorchester   02125
# 6152       Gabi                 f               Back Bay   02116
# 6153       Will                 f               Downtown   02116
# 6154      Hilal                 t               Brighton   02446
#
#            property_type        room_type  \
# 0              Apartment  Entire home/apt
# 1            Guest suite  Entire home/apt
# 2            Condominium  Entire home/apt
# 3              Apartment     Private room
# 4              Apartment  Entire home/apt
# 5              Apartment  Entire home/apt
# 6              Apartment  Entire home/apt
# 7     Serviced apartment  Entire home/apt
# 8     Serviced apartment  Entire home/apt
# 9              Apartment  Entire home/apt
# 10             Apartment  Entire home/apt
# 11             Apartment  Entire home/apt
# 12    Serviced apartment  Entire home/apt
# 13    Serviced apartment  Entire home/apt
# 14    Serviced apartment  Entire home/apt
# 15             Apartment  Entire home/apt
# 16             Apartment  Entire home/apt
# 17             Apartment  Entire home/apt
# 18           Condominium  Entire home/apt
# 19    Serviced apartment  Entire home/apt
# 20             Apartment  Entire home/apt
# 21    Serviced apartment  Entire home/apt
# 22             Apartment  Entire home/apt
# 23    Serviced apartment  Entire home/apt
# 24     Bed and breakfast     Private room
# 25             Apartment  Entire home/apt
# 26    Serviced apartment  Entire home/apt
# 27                  Boat  Entire home/apt
# 28             Apartment  Entire home/apt
# 29             Apartment  Entire home/apt
# ...                  ...              ...
# 6125           Apartment     Private room
# 6126           Apartment     Private room
# 6127           Apartment  Entire home/apt
# 6128               House     Private room
# 6129           Apartment  Entire home/apt
# 6130               House     Private room
# 6131               House     Private room
# 6132           Apartment     Private room
# 6133           Apartment     Private room
# 6134           Apartment  Entire home/apt
# 6135         Condominium  Entire home/apt
# 6136           Apartment     Private room
# 6137           Apartment  Entire home/apt
# 6138           Apartment  Entire home/apt
# 6139         Condominium     Private room
# 6140               House     Private room
# 6141           Apartment  Entire home/apt
# 6142               House     Private room
# 6143           Apartment     Private room
# 6144           Apartment  Entire home/apt
# 6145           Apartment     Private room
# 6146         Condominium  Entire home/apt
# 6147               House     Private room
# 6148           Apartment  Entire home/apt
# 6149         Condominium  Entire home/apt
# 6150           Camper/RV     Private room
# 6151               House     Private room
# 6152           Apartment  Entire home/apt
# 6153           Apartment     Private room
# 6154           Apartment     Private room
#
#                                               amenities instant_bookable  \
# 0     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                f
# 1     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                t
# 2     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                t
# 3     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                f
# 4     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 5     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 6     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 7     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 8     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 9     {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 10    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 11    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 12    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 13    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 14    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 15    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 16    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 17    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 18    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 19    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                f
# 20    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 21    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                t
# 22    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 23    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 24    {Internet,Wifi,"Air conditioning",Heating,"Smo...                t
# 25    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 26    {TV,"Cable TV",Internet,Wifi,"Air conditioning...                f
# 27    {TV,Internet,Wifi,Kitchen,"Paid parking off pr...                f
# 28    {TV,"Cable TV",Internet,"Air conditioning","Wh...                f
# 29    {TV,"Cable TV",Internet,"Air conditioning","Wh...                f
# ...                                                 ...              ...
# 6125  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                t
# 6126  {TV,Wifi,Kitchen,"Free parking on premises",He...                t
# 6127  {Wifi,"Air conditioning",Kitchen,Heating,"Smok...                t
# 6128  {TV,Wifi,"Air conditioning",Kitchen,"Pets allo...                t
# 6129  {TV,"Cable TV",Wifi,"Air conditioning","Paid p...                t
# 6130  {TV,Wifi,"Air conditioning",Kitchen,"Free park...                t
# 6131  {Wifi,"Air conditioning","Pets allowed","Free ...                t
# 6132  {Wifi,"Air conditioning",Kitchen,"Free parking...                t
# 6133  {Wifi,"Air conditioning",Kitchen,Heating,Washe...                t
# 6134  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...                t
# 6135  {TV,Wifi,Kitchen,Heating,Washer,Dryer,"Smoke d...                t
# 6136  {TV,Wifi,Kitchen,"Free parking on premises",He...                t
# 6137  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...                t
# 6138  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                t
# 6139  {Wifi,"Air conditioning",Heating,Washer,Dryer,...                f
# 6140  {Wifi,"Air conditioning","Free parking on prem...                t
# 6141  {TV,"Air conditioning",Kitchen,Elevator,"Indoo...                t
# 6142  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...                t
# 6143  {"Air conditioning",Kitchen,"Pets allowed",Hea...                t
# 6144  {TV,Kitchen,"Pets allowed",Heating,Washer,Drye...                t
# 6145  {Wifi,Kitchen,Heating,"Family/kid friendly",Wa...                t
# 6146  {TV,Wifi,"Air conditioning",Kitchen,"Free park...                f
# 6147  {Wifi,"Air conditioning",Kitchen,Breakfast,Hea...                t
# 6148  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets all...                t
# 6149  {TV,Wifi,"Air conditioning",Pool,Kitchen,Eleva...                t
# 6150  {"Air conditioning",Kitchen,"Pets allowed",Bre...                t
# 6151  {TV,Wifi,Kitchen,"Pets allowed",Breakfast,Heat...                t
# 6152  {TV,Wifi,Kitchen,Breakfast,Heating,"Smoke dete...                f
# 6153  {Wifi,Kitchen,"Paid parking off premises",Heat...                t
# 6154  {Wifi,Kitchen,"Paid parking off premises",Heat...                t
#
#               cancellation_policy
# 0                 super_strict_30
# 1     strict_14_with_grace_period
# 2     strict_14_with_grace_period
# 3                        moderate
# 4     strict_14_with_grace_period
# 5     strict_14_with_grace_period
# 6                 super_strict_30
# 7                 super_strict_30
# 8                 super_strict_30
# 9                 super_strict_30
# 10                super_strict_30
# 11                super_strict_30
# 12                super_strict_30
# 13                super_strict_30
# 14                super_strict_30
# 15    strict_14_with_grace_period
# 16    strict_14_with_grace_period
# 17    strict_14_with_grace_period
# 18    strict_14_with_grace_period
# 19                super_strict_30
# 20                super_strict_30
# 21    strict_14_with_grace_period
# 22                super_strict_30
# 23                super_strict_30
# 24                       moderate
# 25                super_strict_30
# 26                super_strict_30
# 27    strict_14_with_grace_period
# 28                super_strict_30
# 29                super_strict_30
# ...                           ...
# 6125                     moderate
# 6126                     moderate
# 6127                     flexible
# 6128  strict_14_with_grace_period
# 6129  strict_14_with_grace_period
# 6130                     flexible
# 6131  strict_14_with_grace_period
# 6132  strict_14_with_grace_period
# 6133                     flexible
# 6134                     flexible
# 6135                     flexible
# 6136                     flexible
# 6137                     flexible
# 6138                     moderate
# 6139                     flexible
# 6140                     flexible
# 6141                     flexible
# 6142                     flexible
# 6143                     flexible
# 6144                     flexible
# 6145                     flexible
# 6146  strict_14_with_grace_period
# 6147                     flexible
# 6148  strict_14_with_grace_period
# 6149  strict_14_with_grace_period
# 6150                     flexible
# 6151                     flexible
# 6152  strict_14_with_grace_period
# 6153  strict_14_with_grace_period
# 6154  strict_14_with_grace_period
#
# [6155 rows x 9 columns]

# %%
#checking the number of nulls for each feature
print(df_listings_prep1.shape)
df_listings_prep1.isnull().sum().sort_values()
# Out:
# (6155, 19)
# id                          0
# cancellation_policy         0
# instant_bookable            0
# number_of_reviews           0
# price                       0
# amenities                   0
# latitude                    0
# longitude                   0
# room_type                   0
# property_type               0
# zipcode                     0
# neighbourhood_cleansed      0
# accommodates                0
# host_is_superhost           2
# host_name                   2
# beds                        3
# bathrooms                   5
# bedrooms                    6
# cleaning_fee              979
# dtype: int64

# %% [markdown]
# Here, we are going to drop the listings where they have no values about **'host_name', 'beds', 'bathrooms', and 'bedrooms'**. The reason is that we cannot create a model when having missing values, thus, we clean the data as well as create dummy variables for the categorical variables.

# %%
#dropping listings with missing values for host names, beds, bathrooms, and bedrooms
df_listings_prep1 = df_listings_prep1.dropna(axis=0, subset=['host_name', 'beds', 'bathrooms', 'bedrooms'])
print(df_listings_prep1.shape)
df_listings_prep1.isnull().sum().sort_values()
# Out:
# (6140, 19)
# id                          0
# cancellation_policy         0
# instant_bookable            0
# number_of_reviews           0
# price                       0
# amenities                   0
# beds                        0
# latitude                    0
# bedrooms                    0
# accommodates                0
# room_type                   0
# property_type               0
# zipcode                     0
# neighbourhood_cleansed      0
# host_is_superhost           0
# host_name                   0
# bathrooms                   0
# longitude                   0
# cleaning_fee              974
# dtype: int64

# %% [markdown]
# With respect to the **cleaning_fee**, its missing values have been imputed because it could be used for a future analysis. Sometimes, people like to consider the **cleaning_fee** plus the rental price. Here, we will only foucs on the **price** variable. Again, instead of dropping the listings or the feature itself, it has been imputed to be added to our analysis if needed.

# %%
#filling nan values for cleaning_fee with the most frequent cleaning_fee
df_listings_prep1 = df_listings_prep1.apply(lambda x:x.fillna(x.value_counts().index[0]))
df_listings_prep1.isnull().sum()
# Out:
# id                        0
# host_name                 0
# host_is_superhost         0
# neighbourhood_cleansed    0
# zipcode                   0
# property_type             0
# room_type                 0
# accommodates              0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# amenities                 0
# price                     0
# cleaning_fee              0
# number_of_reviews         0
# instant_bookable          0
# cancellation_policy       0
# latitude                  0
# longitude                 0
# dtype: int64

# %%
#assessing the categorical features: which are binary, which are multi-level

#binary
binary_list=[]
#multi-level
multi_level_list=[]

for f in features_cat:
    if (len(df_listings_prep1[f].unique())==2):
        binary_list.append(f)
    elif (len(df_listings_prep1[f].unique())>2):
        multi_level_list.append(f)

# %%
#listing the binary features with their unique values
for b in binary_list:
    print(b, df_listings_prep1[b].unique())
# Out:
# host_is_superhost ['t' 'f']
# instant_bookable ['f' 't']

# %%
#Re-encodeing the binary list
df_listings_prep1['host_is_superhost'] = df_listings_prep1['host_is_superhost'].map({'t': 1, 'f': 0})
df_listings_prep1['instant_bookable'] = df_listings_prep1['instant_bookable'].map({'t': 1, 'f': 0})

# %%
#listing the multilevel features with their unique values
for m in multi_level_list:
    print(m, df_listings_prep1[m].unique())
# Out:
# host_name ['Frank' 'Terry' 'Phil' ... 'Yaling' 'Kashyap' 'Gabi']
# neighbourhood_cleansed ['East Boston' 'Roxbury' 'Roslindale' 'Downtown' 'Fenway' 'Back Bay'
#  'South End' 'North End' 'Dorchester' 'West End' 'Jamaica Plain'
#  'Charlestown' 'Beacon Hill' 'Mission Hill' 'Allston' 'South Boston'
#  'Brighton' 'West Roxbury' 'Bay Village' 'South Boston Waterfront'
#  'Longwood Medical Area' 'Chinatown' 'Mattapan' 'Hyde Park'
#  'Leather District']
# zipcode ['02128' '02119' '02131' '02108' '02111' '02215' '02116' '02115' '02109'
#  '02125' '02114' '02118' '02122' '02130' '02129' '02120' '02134' '02127'
#  '02124' '02135' '02113' '02132' '02121' '02108 02111' '00nan' '02110'
#  '02126' '02136' '02467' '02163' '02145' '02445' '02210' '33131' '02446'
#  '02143' '02141' '02149' '01217' '02421' '02139' '02026']
# property_type ['Apartment' 'Guest suite' 'Condominium' 'Serviced apartment' 'Boat'
#  'House' 'Guesthouse' 'Bed and breakfast' 'Townhouse' 'Loft' 'Bungalow'
#  'Other' 'Villa' 'Boutique hotel' 'Resort' 'Hotel' 'Chalet' 'Tiny house'
#  'Aparthotel' 'Barn' 'Camper/RV']
# room_type ['Entire home/apt' 'Private room' 'Shared room']
# amenities ['{TV,"Cable TV",Wifi,"Air conditioning",Kitchen,"Free parking on premises",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50","Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove}'
#  '{TV,"Cable TV",Internet,Wifi,"Air conditioning","Free street parking",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Private entrance",Bathtub,"Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,"Dishes and silverware","Luggage dropoff allowed","Long term stays allowed"}'
#  '{TV,"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Free street parking",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,"24-hour check-in",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Hot water","Luggage dropoff allowed","Long term stays allowed"}'
#  ...
#  '{TV,Wifi,Kitchen,"Pets allowed",Breakfast,Heating,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Laptop friendly workspace"}'
#  '{TV,Wifi,Kitchen,Breakfast,Heating,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,"Hair dryer",Iron,"Private entrance"}'
#  '{Wifi,Kitchen,"Paid parking off premises",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove}']
# cancellation_policy ['super_strict_30' 'strict_14_with_grace_period' 'moderate' 'flexible'
#  'super_strict_60' 'strict']

# %%
#viewing the dataset after re-encoding the binary list
df_listings_prep1
# Out:
#             id             host_name  host_is_superhost  \
# 0         3781                 Frank                  1
# 1         5506                 Terry                  1
# 2         6695                 Terry                  1
# 3         6976                  Phil                  1
# 4         8789                  Anne                  0
# 5         8792                  Anne                  0
# 8         9827              Seamless                  0
# 9         9855              Seamless                  0
# 10        9857              Seamless                  0
# 11        9858              Seamless                  0
# 12        9859              Seamless                  0
# 13        9860              Seamless                  0
# 14        9870              Seamless                  0
# 15       10730                  Anne                  0
# 16       10811              Michelle                  0
# 17       10813              Michelle                  0
# 18       10986              Michelle                  0
# 19       13589              Seamless                  0
# 20       13592              Seamless                  0
# 21       18711                 Lance                  0
# 22       21891              Seamless                  0
# 25       23370              Seamless                  0
# 26       23668              Seamless                  0
# 27       24240              Gretchen                  1
# 29       25418              Seamless                  0
# 30       27141              Seamless                  0
# 31       27546               Hermina                  0
# 32       27611  Gordon And Alexandra                  0
# 33       28150              Seamless                  0
# 34       29155              Seamless                  0
# ...        ...                   ...                ...
# 6125  32116807               Cortney                  0
# 6126  32125673              Shekeyla                  0
# 6127  32127951                Taylor                  0
# 6128  32133411                 Wendy                  0
# 6129  32133771                 Paige                  0
# 6130  32138377                Rachel                  0
# 6131  32141341                Nicole                  0
# 6132  32147828                Thomas                  0
# 6133  32155120                 Taryn                  0
# 6134  32158419                Hesham                  0
# 6135  32161143             Ekaterina                  0
# 6136  32162031              Mojisola                  0
# 6137  32163609                Ashley                  0
# 6138  32163985              Stayhere                  0
# 6139  32168098                 David                  0
# 6140  32172713               Brigith                  0
# 6141  32180329                  Lola                  0
# 6142  32183321                  Hank                  0
# 6143  32188679                Yaling                  0
# 6144  32195225               Dmitriy                  0
# 6145  32196121               Kashyap                  0
# 6146  32197096                  Alan                  0
# 6147  32202426               Barbara                  0
# 6148  32213220                Taylor                  0
# 6149  32223560                  Jane                  0
# 6150  32234660                Daniel                  0
# 6151  32238109              Courtney                  0
# 6152  32241248                  Gabi                  0
# 6153  32242842                  Will                  0
# 6154  32243378                 Hilal                  1
#
#      neighbourhood_cleansed zipcode       property_type        room_type  \
# 0               East Boston   02128           Apartment  Entire home/apt
# 1                   Roxbury   02119         Guest suite  Entire home/apt
# 2                   Roxbury   02119         Condominium  Entire home/apt
# 3                Roslindale   02131           Apartment     Private room
# 4                  Downtown   02108           Apartment  Entire home/apt
# 5                  Downtown   02108           Apartment  Entire home/apt
# 8                  Downtown   02111  Serviced apartment  Entire home/apt
# 9                    Fenway   02215           Apartment  Entire home/apt
# 10                 Back Bay   02116           Apartment  Entire home/apt
# 11                 Back Bay   02116           Apartment  Entire home/apt
# 12                 Back Bay   02115  Serviced apartment  Entire home/apt
# 13                 Back Bay   02116  Serviced apartment  Entire home/apt
# 14                South End   02116  Serviced apartment  Entire home/apt
# 15                 Downtown   02108           Apartment  Entire home/apt
# 16                 Back Bay   02115           Apartment  Entire home/apt
# 17                 Back Bay   02115           Apartment  Entire home/apt
# 18                North End   02109         Condominium  Entire home/apt
# 19                 Back Bay   02116  Serviced apartment  Entire home/apt
# 20                 Back Bay   02116           Apartment  Entire home/apt
# 21               Dorchester   02125  Serviced apartment  Entire home/apt
# 22                 Downtown   02111           Apartment  Entire home/apt
# 25                 Back Bay   02116           Apartment  Entire home/apt
# 26                 West End   02114  Serviced apartment  Entire home/apt
# 27                North End   02109                Boat  Entire home/apt
# 29                 West End   02114           Apartment  Entire home/apt
# 30                South End   02118  Serviced apartment  Entire home/apt
# 31               Dorchester   02122               House     Private room
# 32            Jamaica Plain   02130           Apartment  Entire home/apt
# 33                 Back Bay   02116           Apartment  Entire home/apt
# 34                 Back Bay   02116  Serviced apartment  Entire home/apt
# ...                     ...     ...                 ...              ...
# 6125          Jamaica Plain   02130           Apartment     Private room
# 6126                Allston   02134           Apartment     Private room
# 6127            East Boston   02128           Apartment  Entire home/apt
# 6128                Roxbury   02119               House     Private room
# 6129               Downtown   02109           Apartment  Entire home/apt
# 6130               Brighton   02135               House     Private room
# 6131          Jamaica Plain   02130               House     Private room
# 6132               West End   02114           Apartment     Private room
# 6133             Dorchester   02122           Apartment     Private room
# 6134           Mission Hill   02130           Apartment  Entire home/apt
# 6135            Beacon Hill   02114         Condominium  Entire home/apt
# 6136             Dorchester   02124           Apartment     Private room
# 6137               West End   02114           Apartment  Entire home/apt
# 6138                Roxbury   02119           Apartment  Entire home/apt
# 6139          Jamaica Plain   02130         Condominium     Private room
# 6140           Mission Hill   02120               House     Private room
# 6141               Back Bay   02116           Apartment  Entire home/apt
# 6142                Allston   02134               House     Private room
# 6143                Allston   02134           Apartment     Private room
# 6144           South Boston   02127           Apartment  Entire home/apt
# 6145               Brighton   02135           Apartment     Private room
# 6146             Dorchester   02121         Condominium  Entire home/apt
# 6147                Allston   02139               House     Private room
# 6148                 Fenway   02215           Apartment  Entire home/apt
# 6149               Downtown   02109         Condominium  Entire home/apt
# 6150           West Roxbury   02132           Camper/RV     Private room
# 6151             Dorchester   02125               House     Private room
# 6152               Back Bay   02116           Apartment  Entire home/apt
# 6153               Downtown   02116           Apartment     Private room
# 6154               Brighton   02446           Apartment     Private room
#
#       accommodates  bathrooms  bedrooms  beds  \
# 0              2.0        1.0       1.0   1.0
# 1              2.0        1.0       1.0   1.0
# 2              4.0        1.0       1.0   2.0
# 3              2.0        1.0       1.0   1.0
# 4              2.0        1.0       1.0   1.0
# 5              2.0        1.0       1.0   1.0
# 8              2.0        1.0       1.0   1.0
# 9              3.0        1.0       1.0   1.0
# 10             4.0        1.0       2.0   2.0
# 11             6.0        1.0       2.0   2.0
# 12             2.0        1.0       1.0   1.0
# 13             2.0        1.0       1.0   1.0
# 14             2.0        1.0       1.0   1.0
# 15             2.0        1.0       1.0   1.0
# 16             3.0        1.0       0.0   2.0
# 17             3.0        1.0       0.0   1.0
# 18             2.0        1.0       0.0   1.0
# 19             6.0        2.0       3.0   3.0
# 20             4.0        1.5       2.0   2.0
# 21             7.0        1.0       3.0   3.0
# 22             4.0        1.0       2.0   2.0
# 25             2.0        1.0       1.0   1.0
# 26             2.0        1.0       1.0   1.0
# 27             5.0        2.0       2.0   3.0
# 29             2.0        1.0       1.0   1.0
# 30             2.0        1.0       1.0   1.0
# 31             4.0        1.0       1.0   2.0
# 32             2.0        1.0       1.0   1.0
# 33             2.0        1.0       1.0   1.0
# 34             6.0        1.5       3.0   3.0
# ...            ...        ...       ...   ...
# 6125           2.0        1.0       1.0   1.0
# 6126           2.0        1.0       1.0   1.0
# 6127           5.0        1.0       2.0   2.0
# 6128           3.0        1.5       1.0   2.0
# 6129           2.0        1.0       0.0   1.0
# 6130           4.0        1.5       3.0   3.0
# 6131           5.0        2.0       1.0   4.0
# 6132           2.0        1.0       1.0   1.0
# 6133           2.0        1.0       1.0   1.0
# 6134           4.0        1.0       2.0   3.0
# 6135           3.0        1.0       2.0   2.0
# 6136           2.0        1.0       1.0   1.0
# 6137           3.0        1.0       1.0   1.0
# 6138           4.0        1.0       2.0   2.0
# 6139           2.0        1.0       1.0   1.0
# 6140           1.0        1.0       1.0   1.0
# 6141           5.0        1.0       2.0   1.0
# 6142           2.0        1.0       1.0   1.0
# 6143           1.0        1.0       0.0   1.0
# 6144           4.0        1.5       2.0   1.0
# 6145           2.0        1.0       1.0   1.0
# 6146           4.0        1.0       1.0   2.0
# 6147           2.0        1.0       1.0   2.0
# 6148           3.0        1.0       0.0   2.0
# 6149           4.0        1.0       1.0   1.0
# 6150           6.0        1.0       1.0   3.0
# 6151           2.0        1.0       1.0   1.0
# 6152           4.0        1.0       1.0   2.0
# 6153           2.0        1.0       1.0   1.0
# 6154           3.0        1.0       1.0   1.0
#
#                                               amenities  price  cleaning_fee  \
# 0     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  125.0          75.0
# 1     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  145.0          40.0
# 2     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  169.0          70.0
# 3     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   65.0           0.0
# 4     {TV,"Cable TV",Internet,Wifi,"Air conditioning...   99.0         250.0
# 5     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  154.0         250.0
# 8     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  389.0         150.0
# 9     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  259.0         150.0
# 10    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  342.0         100.0
# 11    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  489.0         100.0
# 12    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  179.0         100.0
# 13    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  259.0         100.0
# 14    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  279.0         100.0
# 15    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  150.0         250.0
# 16    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  179.0         100.0
# 17    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  179.0         100.0
# 18    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  115.0         145.0
# 19    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  389.0         100.0
# 20    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  359.0         100.0
# 21    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  126.0         120.0
# 22    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  289.0         200.0
# 25    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  289.0         150.0
# 26    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  249.0         150.0
# 27    {TV,Internet,Wifi,Kitchen,"Paid parking off pr...  275.0           0.0
# 29    {TV,"Cable TV",Internet,"Air conditioning","Wh...  279.0         200.0
# 30    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  279.0         100.0
# 31    {"Cable TV",Internet,Wifi,Kitchen,Heating,"Fam...   55.0          25.0
# 32    {Wifi,Kitchen,"Free street parking",Heating,"S...  175.0          60.0
# 33    {TV,"Cable TV",Internet,Wifi,"Air conditioning...  184.0         100.0
# 34    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  451.0         100.0
# ...                                                 ...    ...           ...
# 6125  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  120.0          35.0
# 6126  {TV,Wifi,Kitchen,"Free parking on premises",He...   60.0          15.0
# 6127  {Wifi,"Air conditioning",Kitchen,Heating,"Smok...  143.0          40.0
# 6128  {TV,Wifi,"Air conditioning",Kitchen,"Pets allo...   70.0          25.0
# 6129  {TV,"Cable TV",Wifi,"Air conditioning","Paid p...  100.0          60.0
# 6130  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   65.0          20.0
# 6131  {Wifi,"Air conditioning","Pets allowed","Free ...  200.0          30.0
# 6132  {Wifi,"Air conditioning",Kitchen,"Free parking...  125.0          40.0
# 6133  {Wifi,"Air conditioning",Kitchen,Heating,Washe...   43.0         100.0
# 6134  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...  160.0         100.0
# 6135  {TV,Wifi,Kitchen,Heating,Washer,Dryer,"Smoke d...  160.0         100.0
# 6136  {TV,Wifi,Kitchen,"Free parking on premises",He...   45.0           0.0
# 6137  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...  109.0          30.0
# 6138  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  199.0          25.0
# 6139  {Wifi,"Air conditioning",Heating,Washer,Dryer,...   85.0         100.0
# 6140  {Wifi,"Air conditioning","Free parking on prem...   60.0         100.0
# 6141  {TV,"Air conditioning",Kitchen,Elevator,"Indoo...  220.0         100.0
# 6142  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...   59.0          25.0
# 6143  {"Air conditioning",Kitchen,"Pets allowed",Hea...   60.0         100.0
# 6144  {TV,Kitchen,"Pets allowed",Heating,Washer,Drye...  200.0         100.0
# 6145  {Wifi,Kitchen,Heating,"Family/kid friendly",Wa...   45.0         100.0
# 6146  {TV,Wifi,"Air conditioning",Kitchen,"Free park...   75.0         100.0
# 6147  {Wifi,"Air conditioning",Kitchen,Breakfast,Hea...   80.0         100.0
# 6148  {TV,"Cable TV",Internet,Wifi,Kitchen,"Pets all...  110.0         100.0
# 6149  {TV,Wifi,"Air conditioning",Pool,Kitchen,Eleva...  250.0         100.0
# 6150  {"Air conditioning",Kitchen,"Pets allowed",Bre...  125.0         100.0
# 6151  {TV,Wifi,Kitchen,"Pets allowed",Breakfast,Heat...   75.0         100.0
# 6152  {TV,Wifi,Kitchen,Breakfast,Heating,"Smoke dete...   80.0          25.0
# 6153  {Wifi,Kitchen,"Paid parking off premises",Heat...   60.0          40.0
# 6154  {Wifi,Kitchen,"Paid parking off premises",Heat...   66.0           8.0
#
#       number_of_reviews  instant_bookable          cancellation_policy  \
# 0                  14.0                 0              super_strict_30
# 1                  80.0                 1  strict_14_with_grace_period
# 2                  85.0                 1  strict_14_with_grace_period
# 3                  75.0                 0                     moderate
# 4                  22.0                 0  strict_14_with_grace_period
# 5                  24.0                 0  strict_14_with_grace_period
# 8                   8.0                 0              super_strict_30
# 9                   3.0                 0              super_strict_30
# 10                 25.0                 0              super_strict_30
# 11                  1.0                 0              super_strict_30
# 12                  3.0                 0              super_strict_30
# 13                 22.0                 0              super_strict_30
# 14                  8.0                 0              super_strict_30
# 15                 27.0                 0  strict_14_with_grace_period
# 16                  7.0                 0  strict_14_with_grace_period
# 17                  1.0                 0  strict_14_with_grace_period
# 18                  2.0                 0  strict_14_with_grace_period
# 19                 63.0                 0              super_strict_30
# 20                 20.0                 0              super_strict_30
# 21                 43.0                 1  strict_14_with_grace_period
# 22                 21.0                 0              super_strict_30
# 25                  5.0                 0              super_strict_30
# 26                  0.0                 0              super_strict_30
# 27                 82.0                 0  strict_14_with_grace_period
# 29                  4.0                 0              super_strict_30
# 30                  4.0                 0              super_strict_30
# 31                234.0                 1                     flexible
# 32                 15.0                 1  strict_14_with_grace_period
# 33                 21.0                 0              super_strict_30
# 34                 33.0                 0              super_strict_30
# ...                 ...               ...                          ...
# 6125                0.0                 1                     moderate
# 6126                0.0                 1                     moderate
# 6127                0.0                 1                     flexible
# 6128                0.0                 1  strict_14_with_grace_period
# 6129                0.0                 1  strict_14_with_grace_period
# 6130                0.0                 1                     flexible
# 6131                0.0                 1  strict_14_with_grace_period
# 6132                0.0                 1  strict_14_with_grace_period
# 6133                0.0                 1                     flexible
# 6134                0.0                 1                     flexible
# 6135                0.0                 1                     flexible
# 6136                0.0                 1                     flexible
# 6137                1.0                 1                     flexible
# 6138                0.0                 1                     moderate
# 6139                0.0                 0                     flexible
# 6140                0.0                 1                     flexible
# 6141                0.0                 1                     flexible
# 6142                0.0                 1                     flexible
# 6143                0.0                 1                     flexible
# 6144                0.0                 1                     flexible
# 6145                0.0                 1                     flexible
# 6146                0.0                 0  strict_14_with_grace_period
# 6147                0.0                 1                     flexible
# 6148                0.0                 1  strict_14_with_grace_period
# 6149                0.0                 1  strict_14_with_grace_period
# 6150                0.0                 1                     flexible
# 6151                0.0                 1                     flexible
# 6152                0.0                 0  strict_14_with_grace_period
# 6153                0.0                 1  strict_14_with_grace_period
# 6154                0.0                 1  strict_14_with_grace_period
#
#        latitude  longitude
# 0     42.365241 -71.029361
# 1     42.329808 -71.095595
# 2     42.329941 -71.093505
# 3     42.292438 -71.135765
# 4     42.359187 -71.062651
# 5     42.358497 -71.062011
# 8     42.352149 -71.063301
# 9     42.343371 -71.098708
# 10    42.354290 -71.072772
# 11    42.344471 -71.081786
# 12    42.350260 -71.084718
# 13    42.354115 -71.074414
# 14    42.344227 -71.077878
# 15    42.358403 -71.061850
# 16    42.349730 -71.087924
# 17    42.349613 -71.089038
# 18    42.363520 -71.050754
# 19    42.355263 -71.072793
# 20    42.353763 -71.074239
# 21    42.323286 -71.062103
# 22    42.352179 -71.063160
# 25    42.346091 -71.078578
# 26    42.363865 -71.068950
# 27    42.363660 -71.050232
# 29    42.364945 -71.067668
# 30    42.342586 -71.079691
# 31    42.298349 -71.059104
# 32    42.315565 -71.114827
# 33    42.353975 -71.072612
# 34    42.354328 -71.073521
# ...         ...        ...
# 6125  42.321519 -71.110608
# 6126  42.362714 -71.131194
# 6127  42.373256 -71.032211
# 6128  42.326400 -71.092240
# 6129  42.359055 -71.052996
# 6130  42.354935 -71.165600
# 6131  42.325101 -71.105237
# 6132  42.365379 -71.069163
# 6133  42.288390 -71.050601
# 6134  42.331076 -71.110691
# 6135  42.360359 -71.066792
# 6136  42.287114 -71.092115
# 6137  42.361173 -71.070311
# 6138  42.327272 -71.080344
# 6139  42.319170 -71.105199
# 6140  42.330545 -71.101546
# 6141  42.345382 -71.079692
# 6142  42.350709 -71.134464
# 6143  42.352673 -71.129030
# 6144  42.332255 -71.030875
# 6145  42.346257 -71.140473
# 6146  42.300713 -71.084060
# 6147  42.355790 -71.110322
# 6148  42.346640 -71.103684
# 6149  42.359254 -71.053765
# 6150  42.262505 -71.151490
# 6151  42.318001 -71.053537
# 6152  42.349531 -71.082424
# 6153  42.351701 -71.065359
# 6154  42.340967 -71.134066
#
# [6140 rows x 19 columns]

# %% [markdown]
# ---
# ### <font color=blue> Q3. Who are the hosts with the most number of airbnb listings?

# %%
hosts_count = df_listings_prep1.groupby('host_name').count()['id'].sort_values(ascending=False)
hosts_count[hosts_count >= 20]
# Out:
# host_name
# Sonder                306
# Kara                  155
# Bluebird              153
# Mike                  142
# Brent                  89
# Stay Alfred            85
# Jen                    80
# Corp Condos & Apts     70
# Sonder (Boston)        58
# Maverick               56
# Marie                  54
# Matthew                49
# Will                   48
# Domio                  44
# Taylor                 43
# Alex                   41
# Paige                  40
# Blueground             39
# Huggy                  36
# Inn Boston             36
# Michelle               34
# Michael                33
# Ken                    33
# David                  32
# Mario                  31
# Chris                  30
# Jason                  29
# Luxurious              28
# Seamless               28
# Jonathan               27
# Jennifer               26
# Kevin                  26
# Robert                 25
# Susan                  24
# Anne                   24
# Kiki                   24
# Lance                  23
# Nav                    22
# Adam                   22
# John                   22
# Sarah                  21
# Stephanie              20
# Name: id, dtype: int64

# %%
h_count = df_listings_prep1.groupby('host_name').count()['id']
h_count = h_count[h_count >= 10]
h_count = h_count.sort_values(ascending=False)
x = h_count.index
y = h_count
y_cum = np.cumsum(y)
y_perc = 100*y_cum/y.sum()

trace1 = dict(type='bar',
    x=x,
    y=y,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5)),
    name='Count of Listings',
    opacity=0.6
)

trace2 = dict(type='scatter',
    x=x,
    y=y_perc,
    marker=dict(
        color='#7F7F7F'
    ),
    line=dict(color= '#7F7F7F', width= 1.5),
    name='Cumulative Listings Percent of Total (%)',
    xaxis='x1', 
    yaxis='y2' 
)
    
data = [trace1, trace2]
layout = go.Layout(
    title='Number of Listings by Host',
    legend= dict(x=-.1, y=1.2),
    yaxis=dict(
        title='Count of Listings'
    ),
    yaxis2=dict(
        title='Percent of Total Listings (%)',
        range=[0,100],
        overlaying='y',
        anchor='x',
        side='right'
        )
    )

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Percent of listings by Host')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/476.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# As we can see from the bar chart, Sonder has around 10% of the 6140 listings, followed by Kara with 155, Bluebird with 154, and Mike with 142 listings. Those four hosts represent about 25% of the total listings. The other hosts' number of listings range from 1 to 89 listings.
#
# According to Inside Airbnb, it is vital to notice that "A host may list separate rooms in the same apartment, or multiple apartments or homes available in their entirety. Hosts with multiple listings are more likely to be running a business, are unlikely to be living in the property, and in violation of most short term rental laws designed to protect residential housing."

# %% [markdown]
# ---
# ### <font color=blue> Q4. Which neighborhoods have the most number of listing in Boston?

# %%
df_listings_prep1['neighbourhood_cleansed'].value_counts()
# Out:
# Dorchester                 536
# Jamaica Plain              513
# Back Bay                   492
# Downtown                   452
# South End                  439
# Fenway                     438
# Brighton                   358
# South Boston               337
# Allston                    329
# Roxbury                    319
# East Boston                311
# Beacon Hill                255
# North End                  244
# Mission Hill               214
# Charlestown                156
# West End                   154
# Chinatown                  139
# Roslindale                 117
# South Boston Waterfront     76
# Mattapan                    75
# West Roxbury                70
# Hyde Park                   59
# Bay Village                 39
# Longwood Medical Area       11
# Leather District             7
# Name: neighbourhood_cleansed, dtype: int64

# %%
n_count = df_listings_prep1.groupby('neighbourhood_cleansed').count()['id']
n_count = n_count.sort_values(ascending=False)
x = n_count.index
y = n_count
y_cum = np.cumsum(y)
y_perc = 100*y_cum/y.sum()

trace1 = dict(type='bar',
    x=x,
    y=y,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5)),
    name='Count of Listings',
    opacity=0.6
)

trace2 = dict(type='scatter',
    x=x,
    y=y_perc,
    marker=dict(
        color='#7F7F7F'
    ),
    line=dict(color= '#7F7F7F', width= 1.5),
    name='Cumulative Listings Percent of Total (%)',
    xaxis='x1', 
    yaxis='y2' 
)
    
data = [trace1, trace2]
layout = go.Layout(
    title='Number of Listings by neighbourhood',
    legend= dict(x=-.1, y=1.2),
    yaxis=dict(
        title='Count of Listings'
    ),
    yaxis2=dict(
        title='Percent of Total Listings (%)',
        range=[0,100],
        overlaying='y',
        anchor='x',
        side='right'
        )
    )

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Percent of listings by neighbourhood')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/478.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Next, we will investigate the price distribution to make sure outliers, hosts who list at above and beyond the reasonable prices per night.

# %%
x = df_listings_prep1.price

annotations={}

trace1 = go.Histogram(
    x=x,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5)),
    name='Price',
    opacity=0.6
)

data = [trace1]
layout = go.Layout(
    title = "Price Distributions",
    xaxis=dict(
        title='Price'),
    yaxis=dict(
        title='Count'))

layout.update(dict(annotations=[go.Annotation(text="Outliers all after", x=1000, y=0)]))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, annotations=annotations, filename='Price Distribution')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/484.embed" height="525px" width="100%"></iframe>

# %%
x = df_listings_prep1.price[df_listings_prep1.price <=1000]

trace1 = go.Histogram(
    x=x,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5)),
    name='Price',
    opacity=0.6
)

data = [trace1]
layout = go.Layout(
    title = "Price Distributions <1000",
    xaxis=dict(
        title='Price'),
    yaxis=dict(
        title='Count'))

layout.update(dict(annotations=[go.Annotation(text="Outliers all after", x=500, y=0)]))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Price Distribution <1000')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/500.embed" height="525px" width="100%"></iframe>

# %%
x = df_listings_prep1.price[df_listings_prep1.price <=500]

trace1 = go.Histogram(
    x=x,
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5)),
    name='Price',
    opacity=0.6
)

data = [trace1]
layout = go.Layout(
    title = "Price Distributions <500",
    xaxis=dict(
        title='Price'),
    yaxis=dict(
        title='Count'))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Price Distribution <500')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/502.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Based on the histogram that illustrates the price distribution among all listings, a maximum of 500 dollars per night is reasonable comparing with higher rates that have been dropped; it's high though, as the distribution explicates that most listings occur at the range between 50 up to 200 dollars per night. However, it will the cutpoint for the maximum rate per night in our further analysis.

# %%
#setting the final dataset to include only listings within the price up to $500
df_listings_prep1 = df_listings_prep1[df_listings_prep1.price <=500]
print(df_listings_prep1.price.max())
# Out:
# 500.0

# %% [markdown]
# ---
# ### <font color=blue> Q5. Which neighborhoods are considered as the most expensive in Boston?

# %%
n_exp = df_listings_prep1.groupby('neighbourhood_cleansed')
n_exp = n_exp['price'].describe().drop(['std', '25%', '50%', '75%'], axis=1).sort_values(by='mean', ascending=False)
n_exp
# Out:
#                          count        mean   min    max
# neighbourhood_cleansed
# Chinatown                130.0  226.430769  54.0  500.0
# South Boston Waterfront   70.0  223.385714  49.0  450.0
# West End                 136.0  218.867647  49.0  499.0
# Downtown                 428.0  215.432243  49.0  500.0
# Back Bay                 427.0  215.009368  40.0  500.0
# Leather District           6.0  210.500000  65.0  375.0
# Fenway                   429.0  200.037296  20.0  500.0
# Charlestown              147.0  192.360544  10.0  500.0
# South Boston             322.0  191.214286  48.0  500.0
# South End                429.0  187.114219   0.0  500.0
# Mission Hill             204.0  181.039216  18.0  500.0
# Bay Village               37.0  180.675676  95.0  500.0
# North End                238.0  176.369748  45.0  500.0
# Beacon Hill              247.0  173.870445  50.0  499.0
# Jamaica Plain            507.0  139.800789  21.0  500.0
# East Boston              310.0  125.229032   0.0  400.0
# Allston                  320.0  117.596875  10.0  500.0
# Longwood Medical Area     11.0  115.727273  45.0  196.0
# Roxbury                  307.0  106.371336  17.0  500.0
# Brighton                 354.0  101.059322  22.0  500.0
# West Roxbury              69.0   95.594203  33.0  350.0
# Dorchester               528.0   92.871212   0.0  500.0
# Mattapan                  75.0   84.520000  28.0  419.0
# Roslindale               117.0   84.094017  24.0  300.0
# Hyde Park                 59.0   81.118644  25.0  275.0

# %%
#creating numpy arraies for the top six neighbourhoods' prices: 'Chinatown', 'South Boston Waterfront', 'West End', 'Downtown', 'Back Bay', and 'Fenway'
#'Leather District' was skiped becuase it has only 6 listings, a very small number compared to other neighbourhoods' listings.

chinatown_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'Chinatown']
chinatown_p = np.array(chinatown_p.price)

back_bay_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'Back Bay']
back_bay_p = np.array(back_bay_p.price)

west_end_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'West End']
west_end_p = np.array(west_end_p.price)

waterfront_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'South Boston Waterfront']
waterfront_p = np.array(waterfront_p.price)

downtown_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'Downtown']
downtown_p = np.array(downtown_p.price)

fenway_p = df_listings_prep1[df_listings_prep1.neighbourhood_cleansed == 'Fenway']
fenway_p = np.array(fenway_p.price)

# %%
x_data = ['Chinatown', 'West End', 'Downtown', 'South Boston Waterfront', 'Back Bay', 'Fenway']

y0 = chinatown_p
y1 = west_end_p
y2 = downtown_p
y3 = waterfront_p
y4 = back_bay_p
y5 = fenway_p

y_data = [y0,y1,y2,y3,y4,y5]

colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)']

traces = []

for xd, yd, cls in zip(x_data, y_data, colors):
        traces.append(go.Box(
            y=yd,
            name=xd,
            boxmean=True,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
        ))

layout = go.Layout(
    title='Comparsion between the top most expensive neighborhoods',
    yaxis=dict(
        autorange=True,
        showgrid=True,
        zeroline=False,
        dtick=40,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
    showlegend=False
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='Most expensive neighbourhood')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/482.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# While the bar plot shows that Dorchester and Jamaica Plain the top two neighborhoods with respect to the number of listings in the dataset, the box plots illustrate a complete comparison between the top most expensive neighborhoods that excludes the top two mentioned neighborhoods. The plots represent the table that describes the prices for each neighborhood.
#
#       1. Chinatown, which is part of the Downtown, has the highest average price per night around $226, while 'Fenway' has $200 per night among the six most expensive neighborhoods.
#       2. Most listings range between $289 per night and $131 per night, which indicates the reasonable price at one of these neighborhoods.
#
# *The numbers will be elaborated even further with heatmap generated below as it shows the areas not only where the rates per night are high, but also where most of the listings are located.*

# %%
#Get the locations from the data set
locations = df_listings_prep1[['latitude', 'longitude']]
#Get the price from the data
prices = df_listings_prep1['price']
#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=prices))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
#
# <center> <img src="https://i.etsystatic.com/5206469/r/il/4273de/597430359/il_fullxfull.597430359_a122.jpg" style="width:400px;"/>
#
# Art by [Carrie Wagner](https://www.etsy.com/shop/SepiaLepus?ref=simple-shop-header-name&listing_id=208367563) on [Etsy](https://www.etsy.com/?ref=lgo)

# %% [markdown]
# ---
# ### <font color=blue> Q6. Which are the popular neighbourhoods based on the average number of reviews?

# %%
popularity = df_listings_prep1.groupby('neighbourhood_cleansed')
popularity = popularity['number_of_reviews'].describe().drop(['std', '25%', '50%', 'min', '75%'], axis=1).sort_values(by='mean', ascending=False)
popularity = popularity[popularity['count'] > 120]
popularity
# Out:
#                         count       mean    max
# neighbourhood_cleansed
# North End               238.0  68.184874  491.0
# East Boston             310.0  56.748387  444.0
# Dorchester              528.0  42.458333  513.0
# Beacon Hill             247.0  41.170040  290.0
# Roxbury                 307.0  38.068404  371.0
# South End               429.0  37.079254  358.0
# Jamaica Plain           507.0  33.781065  424.0
# South Boston            322.0  32.739130  413.0
# Charlestown             147.0  31.346939  321.0
# Back Bay                427.0  29.292740  507.0
# Downtown                428.0  26.116822  299.0
# Brighton                354.0  25.864407  299.0
# Allston                 320.0  22.500000  257.0
# Chinatown               130.0  19.684615  167.0
# Fenway                  429.0  16.587413  232.0
# West End                136.0  14.580882  205.0
# Mission Hill            204.0  13.740196  626.0

# %% [markdown]
# *The results for the popular neighborhoods based on the average number of reviews is embellished with the heatmap generated below as it confirms that North Ends has the highest reviews although it doesn't have the highest number of listings.*

# %%
#Get the locations from the data set
locations = df_listings_prep1[['latitude', 'longitude']]
#Get the price from the data
prices = df_listings_prep1['number_of_reviews']
#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=prices))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ---
# ### <font color=blue> Q7. Which type of room has the majority of listings in Boston airbnb?

# %%
rooms_df = df_listings_prep1['room_type'].value_counts()
rooms_df
# Out:
# Entire home/apt    3775
# Private room       2061
# Shared room          71
# Name: room_type, dtype: int64

# %%
rooms = df_listings_prep1['room_type'].value_counts()
labels = rooms_df.index
values = rooms
colors = ['slateblue', 'aquamarine', 'mediumblue']


trace1 = go.Pie(labels=labels, values=round(100*values/values.sum(), 2),
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               hole=0.9,
               showlegend=False,
               opacity=0.3,
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=2)))


trace2 = go.Bar(
    x=[rooms_df.index[0]],
    y=[4002],
    name=rooms_df.index[0],
    marker=dict(
        color='slateblue',
        line=dict(
            color='slateblue',
            width=1.5,
        )
    ),
    opacity=0.4
)

trace3 = go.Bar(
    x=[rooms_df.index[1]],
    y=[2066],
    name=rooms_df.index[1],
    marker=dict(
        color='aquamarine',
        line=dict(
            color='aquamarine',
            width=1.5,
        )
    ),
    opacity=0.4
)

trace4 = go.Bar(
    x=[rooms_df.index[2]],
    y=[72],
    name=rooms_df.index[2],
    marker=dict(
        color='mediumblue',
        line=dict(
            color='mediumblue',
            width=1.5,
        )
    ),
    opacity=0.3
)

data = go.Data([trace1, trace2, trace3, trace4])

layout = go.Layout(
    title='Count of room type',
    xaxis=dict(
        title='Room Type',
        domain=[0.4, 0.6]
    ),
    yaxis=dict(
        title='Count',
        domain=[0.4, 0.7]
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='percent of room types')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/480.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Airbnb hosts can list one or all of these room types: entire homes/apartments, private or shared rooms. The donut plot shows that entire homes/apartments accounts for 63.9% of the listings with 3775 listings around Boston. Following by private room with 2061 listings and shared room with only 71 listings account for only 1.2%
#
# ---

# %%
#copying the latest dataset
df_listings_prep2 = df_listings_prep1.copy()

# %%
df_listings_prep2.columns
# Out:
# Index(['id', 'host_name', 'host_is_superhost', 'neighbourhood_cleansed',
#        'zipcode', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'amenities', 'price', 'cleaning_fee',
#        'number_of_reviews', 'instant_bookable', 'cancellation_policy',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
#dropping two features not needed for further analysis
df_listings_prep2 = df_listings_prep2.drop(['host_name', 'zipcode', 'latitude', 'longitude'], axis=1)
df_listings_prep2.sample(5)
# Out:
#             id  host_is_superhost neighbourhood_cleansed property_type  \
# 5066  28218323                  0              Chinatown     Apartment
# 536    4568116                  1                Roxbury     Townhouse
# 235    1545185                  0               Brighton   Guest suite
# 2075  15451419                  0              South End     Apartment
# 3441  21648941                  0               Brighton         House
#
#             room_type  accommodates  bathrooms  bedrooms  beds  \
# 5066  Entire home/apt           4.0        1.0       1.0   2.0
# 536   Entire home/apt           2.0        1.0       0.0   1.0
# 235   Entire home/apt           4.0        1.0       1.0   2.0
# 2075  Entire home/apt           3.0        2.0       2.0   2.0
# 3441     Private room           2.0        1.5       1.0   1.0
#
#                                               amenities  price  cleaning_fee  \
# 5066  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...  249.0          59.0
# 536   {TV,"Cable TV",Internet,Wifi,"Air conditioning...  130.0          30.0
# 235   {TV,"Cable TV",Internet,Wifi,"Air conditioning...  140.0         100.0
# 2075  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...  320.0          20.0
# 3441  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...   48.0          30.0
#
#       number_of_reviews  instant_bookable cancellation_policy
# 5066                6.0                 1            moderate
# 536               371.0                 0            moderate
# 235                92.0                 1            moderate
# 2075                9.0                 1            moderate
# 3441                1.0                 1            moderate

# %%
#assessing the amenities feature
df_listings_prep2.amenities.sample(10)
# Out:
# 5576                                                   {}
# 1596    {TV,"Cable TV",Wifi,"Air conditioning","Paid p...
# 1117    {TV,Internet,Wifi,"Air conditioning",Kitchen,"...
# 3570    {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...
# 680     {TV,"Cable TV",Wifi,"Air conditioning","Free s...
# 315     {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 4685    {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...
# 2944    {TV,Internet,Wifi,"Air conditioning",Kitchen,H...
# 3161    {TV,Wifi,Kitchen,"Free street parking",Heating...
# 120     {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# Name: amenities, dtype: object

# %%
#splitting the amenities and then creating dummies
df_listings_prep2['amenities'] = df_listings_prep2['amenities'].str.replace('[{}" ]', '')
df_amenities = df_listings_prep2.amenities.str.get_dummies(sep = ",")
print(df_amenities.shape)
df_amenities.sample(2)
# Out:
# (5907, 120)
#       24-hourcheck-in  Accessible-heightbed  Accessible-heighttoilet  \
# 3623                0                     0                        0
# 209                 1                     0                        0
#
#       Airconditioning  BBQgrill  Babybath  Babymonitor  \
# 3623                0         0         0            0
# 209                 1         0         0            0
#
#       Babysitterrecommendations  Bathtub  Bathtubwithbathchair  ...  \
# 3623                          0        0                     0  ...
# 209                           0        1                     0  ...
#
#       Wideclearancetobed  Wideclearancetoshower  Widedoorway  Wideentryway  \
# 3623                   0                      0            0             0
# 209                    0                      0            0             0
#
#       Widehallwayclearance  Wifi  Windowguards  toilet  \
# 3623                     0     1             0       0
# 209                      0     1             0       0
#
#       translationmissing:en.hosting_amenity_49  \
# 3623                                         0
# 209                                          0
#
#       translationmissing:en.hosting_amenity_50
# 3623                                         0
# 209                                          0
#
# [2 rows x 120 columns]

# %%
#preparing the categorical features that will be used for modeling
features_cat = df_listings_prep2.select_dtypes(include=['object'])
features_cat = features_cat.drop(['amenities'], axis=1) #dropping the amenities feature as it has already split into 121 dummies

#getting dummies for each categorical feature except amenities
features_cat = pd.get_dummies(features_cat)

#viewing the dataset after creatign the dummies
print(features_cat.shape)
features_cat.sample(2)
# Out:
# (5907, 55)
#       neighbourhood_cleansed_Allston  neighbourhood_cleansed_Back Bay  \
# 4958                               0                                1
# 692                                0                                1
#
#       neighbourhood_cleansed_Bay Village  neighbourhood_cleansed_Beacon Hill  \
# 4958                                   0                                   0
# 692                                    0                                   0
#
#       neighbourhood_cleansed_Brighton  neighbourhood_cleansed_Charlestown  \
# 4958                                0                                   0
# 692                                 0                                   0
#
#       neighbourhood_cleansed_Chinatown  neighbourhood_cleansed_Dorchester  \
# 4958                                 0                                  0
# 692                                  0                                  0
#
#       neighbourhood_cleansed_Downtown  neighbourhood_cleansed_East Boston  \
# 4958                                0                                   0
# 692                                 0                                   0
#
#       ...  property_type_Villa  room_type_Entire home/apt  \
# 4958  ...                    0                          1
# 692   ...                    0                          1
#
#       room_type_Private room  room_type_Shared room  \
# 4958                       0                      0
# 692                        0                      0
#
#       cancellation_policy_flexible  cancellation_policy_moderate  \
# 4958                             0                             0
# 692                              0                             0
#
#       cancellation_policy_strict  \
# 4958                           0
# 692                            0
#
#       cancellation_policy_strict_14_with_grace_period  \
# 4958                                                1
# 692                                                 1
#
#       cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 4958                                    0                                    0
# 692                                     0                                    0
#
# [2 rows x 55 columns]

# %%
#preparing the numerical features that will be used for modeling
features_num = df_listings_prep2.select_dtypes(include=['float', 'int'])
features_num_lst = features_num.columns
print(features_num.shape)
list(features_num_lst)
features_num.sample(2)
# Out:
# (5907, 10)
#             id  host_is_superhost  accommodates  bathrooms  bedrooms  beds  \
# 5615  29901892                  1           2.0        1.0       1.0   1.0
# 1600  13140867                  0           2.0        1.0       1.0   1.0
#
#       price  cleaning_fee  number_of_reviews  instant_bookable
# 5615   52.0          14.0               10.0                 1
# 1600  250.0         125.0              133.0                 1

# %%
#merging all the prepared dataframes created: df_amenities, features_cat, and features_num
df = pd.concat([features_num, features_cat, df_amenities], axis=1, join='inner')
df.sample(10)
# Out:
#             id  host_is_superhost  accommodates  bathrooms  bedrooms  beds  \
# 3032  20228320                  1           3.0        1.0       1.0   1.0
# 1717  13685207                  0           6.0        2.0       3.0   3.0
# 2848  19455818                  0           5.0        2.0       2.0   1.0
# 618    5259996                  0           3.0        1.5       2.0   2.0
# 6020  31571124                  0           5.0        1.0       2.0   3.0
# 5469  29539009                  0           4.0        1.0       0.0   1.0
# 4075  23467213                  0           6.0        3.0       3.0   3.0
# 5922  31073977                  1           2.0        2.0       1.0   1.0
# 5288  29014832                  0           2.0        1.0       1.0   1.0
# 1520  12581300                  0           2.0        1.0       1.0   1.0
#
#       price  cleaning_fee  number_of_reviews  instant_bookable  ...  \
# 3032  195.0          80.0               86.0                 1  ...
# 1717  184.0         154.0               27.0                 1  ...
# 2848  469.0         100.0                0.0                 0  ...
# 618   245.0         175.0                5.0                 0  ...
# 6020  125.0          69.0                0.0                 1  ...
# 5469  133.0         100.0                0.0                 0  ...
# 4075  405.0         147.0               17.0                 1  ...
# 5922   44.0          26.0                2.0                 0  ...
# 5288   70.0          15.0                0.0                 1  ...
# 1520   65.0           5.0               11.0                 0  ...
#
#       Wideclearancetobed  Wideclearancetoshower  Widedoorway  Wideentryway  \
# 3032                   0                      0            0             0
# 1717                   0                      0            0             0
# 2848                   0                      0            0             0
# 618                    0                      0            0             0
# 6020                   0                      0            0             0
# 5469                   0                      0            0             0
# 4075                   0                      0            0             0
# 5922                   0                      0            0             0
# 5288                   0                      0            0             0
# 1520                   0                      0            0             0
#
#       Widehallwayclearance  Wifi  Windowguards  toilet  \
# 3032                     0     1             0       0
# 1717                     0     1             0       0
# 2848                     0     1             0       0
# 618                      0     1             0       0
# 6020                     0     1             0       0
# 5469                     0     1             0       0
# 4075                     0     1             0       0
# 5922                     0     1             0       0
# 5288                     0     1             0       0
# 1520                     0     1             0       0
#
#       translationmissing:en.hosting_amenity_49  \
# 3032                                         0
# 1717                                         0
# 2848                                         0
# 618                                          0
# 6020                                         0
# 5469                                         0
# 4075                                         0
# 5922                                         0
# 5288                                         0
# 1520                                         0
#
#       translationmissing:en.hosting_amenity_50
# 3032                                         0
# 1717                                         0
# 2848                                         0
# 618                                          0
# 6020                                         0
# 5469                                         0
# 4075                                         0
# 5922                                         0
# 5288                                         0
# 1520                                         1
#
# [10 rows x 185 columns]

# %%
#confirming the entire dataframes have been merged correctly with the right list of numerical features, amenities, and dummies for categorical features
print(df.shape)
list(df.columns)
# Out:
# (5907, 185)
# ['id',
#  'host_is_superhost',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'cleaning_fee',
#  'number_of_reviews',
#  'instant_bookable',
#  'neighbourhood_cleansed_Allston',
#  'neighbourhood_cleansed_Back Bay',
#  'neighbourhood_cleansed_Bay Village',
#  'neighbourhood_cleansed_Beacon Hill',
#  'neighbourhood_cleansed_Brighton',
#  'neighbourhood_cleansed_Charlestown',
#  'neighbourhood_cleansed_Chinatown',
#  'neighbourhood_cleansed_Dorchester',
#  'neighbourhood_cleansed_Downtown',
#  'neighbourhood_cleansed_East Boston',
#  'neighbourhood_cleansed_Fenway',
#  'neighbourhood_cleansed_Hyde Park',
#  'neighbourhood_cleansed_Jamaica Plain',
#  'neighbourhood_cleansed_Leather District',
#  'neighbourhood_cleansed_Longwood Medical Area',
#  'neighbourhood_cleansed_Mattapan',
#  'neighbourhood_cleansed_Mission Hill',
#  'neighbourhood_cleansed_North End',
#  'neighbourhood_cleansed_Roslindale',
#  'neighbourhood_cleansed_Roxbury',
#  'neighbourhood_cleansed_South Boston',
#  'neighbourhood_cleansed_South Boston Waterfront',
#  'neighbourhood_cleansed_South End',
#  'neighbourhood_cleansed_West End',
#  'neighbourhood_cleansed_West Roxbury',
#  'property_type_Aparthotel',
#  'property_type_Apartment',
#  'property_type_Barn',
#  'property_type_Bed and breakfast',
#  'property_type_Boat',
#  'property_type_Boutique hotel',
#  'property_type_Bungalow',
#  'property_type_Camper/RV',
#  'property_type_Chalet',
#  'property_type_Condominium',
#  'property_type_Guest suite',
#  'property_type_Guesthouse',
#  'property_type_Hotel',
#  'property_type_House',
#  'property_type_Loft',
#  'property_type_Other',
#  'property_type_Resort',
#  'property_type_Serviced apartment',
#  'property_type_Tiny house',
#  'property_type_Townhouse',
#  'property_type_Villa',
#  'room_type_Entire home/apt',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'cancellation_policy_flexible',
#  'cancellation_policy_moderate',
#  'cancellation_policy_strict',
#  'cancellation_policy_strict_14_with_grace_period',
#  'cancellation_policy_super_strict_30',
#  'cancellation_policy_super_strict_60',
#  '24-hourcheck-in',
#  'Accessible-heightbed',
#  'Accessible-heighttoilet',
#  'Airconditioning',
#  'BBQgrill',
#  'Babybath',
#  'Babymonitor',
#  'Babysitterrecommendations',
#  'Bathtub',
#  'Bathtubwithbathchair',
#  'Beachessentials',
#  'Beachfront',
#  'Bedlinens',
#  'Breakfast',
#  'Buildingstaff',
#  'Buzzer/wirelessintercom',
#  'CableTV',
#  'Carbonmonoxidedetector',
#  'Cat(s)',
#  'Changingtable',
#  'Children’sbooksandtoys',
#  'Children’sdinnerware',
#  'Cleaningbeforecheckout',
#  'Coffeemaker',
#  'Cookingbasics',
#  'Crib',
#  'Disabledparkingspot',
#  'Dishesandsilverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Dryer',
#  'EVcharger',
#  'Electricprofilingbed',
#  'Elevator',
#  'Essentials',
#  'Ethernetconnection',
#  'Extrapillowsandblankets',
#  'Family/kidfriendly',
#  'Fireextinguisher',
#  'Fireplaceguards',
#  'Firmmattress',
#  'Firstaidkit',
#  'Fixedgrabbarsforshower',
#  'Fixedgrabbarsfortoilet',
#  'Flatpathtofrontdoor',
#  'Freeparkingonpremises',
#  'Freestreetparking',
#  'Gameconsole',
#  'Gardenorbackyard',
#  'Gym',
#  'Hairdryer',
#  'Handheldshowerhead',
#  'Hangers',
#  'Heating',
#  'Highchair',
#  'Hostgreetsyou',
#  'Hottub',
#  'Hotwater',
#  'Hotwaterkettle',
#  'Indoorfireplace',
#  'Internet',
#  'Iron',
#  'Keypad',
#  'Kitchen',
#  'Lakeaccess',
#  'Laptopfriendlyworkspace',
#  'Lockbox',
#  'Lockonbedroomdoor',
#  'Longtermstaysallowed',
#  'Luggagedropoffallowed',
#  'Microwave',
#  'Other',
#  'Otherpet(s)',
#  'Outletcovers',
#  'Oven',
#  'Pack’nPlay/travelcrib',
#  'Paidparkingoffpremises',
#  'Paidparkingonpremises',
#  'Patioorbalcony',
#  'Petsallowed',
#  'Petsliveonthisproperty',
#  'Pocketwifi',
#  'Pool',
#  'Privatebathroom',
#  'Privateentrance',
#  'Privatelivingroom',
#  'Refrigerator',
#  'Roll-inshower',
#  'Room-darkeningshades',
#  'Safetycard',
#  'Selfcheck-in',
#  'Shampoo',
#  'Showerchair',
#  'Singlelevelhome',
#  'Ski-in/Ski-out',
#  'Smartlock',
#  'Smokedetector',
#  'Smokingallowed',
#  'Stairgates',
#  'Step-freeaccess',
#  'Stove',
#  'Suitableforevents',
#  'TV',
#  'Tablecornerguards',
#  'Washer',
#  'Washer/Dryer',
#  'Waterfront',
#  'Well-litpathtoentrance',
#  'Wheelchairaccessible',
#  'Wideclearancetobed',
#  'Wideclearancetoshower',
#  'Widedoorway',
#  'Wideentryway',
#  'Widehallwayclearance',
#  'Wifi',
#  'Windowguards',
#  'toilet',
#  'translationmissing:en.hosting_amenity_49',
#  'translationmissing:en.hosting_amenity_50']

# %%
#checking if we have any missing value for any feature
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ---
# # <center>STAGE THREE</center>
# ---

# %% [markdown]
# ## 4. Data Modeling

# %%
#copying the latest dataset
df_model = df.copy()

# %%
#listing the final dataset's features
print(df_model.shape)
list(df_model.columns)
# Out:
# (5907, 185)
# ['id',
#  'host_is_superhost',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'cleaning_fee',
#  'number_of_reviews',
#  'instant_bookable',
#  'neighbourhood_cleansed_Allston',
#  'neighbourhood_cleansed_Back Bay',
#  'neighbourhood_cleansed_Bay Village',
#  'neighbourhood_cleansed_Beacon Hill',
#  'neighbourhood_cleansed_Brighton',
#  'neighbourhood_cleansed_Charlestown',
#  'neighbourhood_cleansed_Chinatown',
#  'neighbourhood_cleansed_Dorchester',
#  'neighbourhood_cleansed_Downtown',
#  'neighbourhood_cleansed_East Boston',
#  'neighbourhood_cleansed_Fenway',
#  'neighbourhood_cleansed_Hyde Park',
#  'neighbourhood_cleansed_Jamaica Plain',
#  'neighbourhood_cleansed_Leather District',
#  'neighbourhood_cleansed_Longwood Medical Area',
#  'neighbourhood_cleansed_Mattapan',
#  'neighbourhood_cleansed_Mission Hill',
#  'neighbourhood_cleansed_North End',
#  'neighbourhood_cleansed_Roslindale',
#  'neighbourhood_cleansed_Roxbury',
#  'neighbourhood_cleansed_South Boston',
#  'neighbourhood_cleansed_South Boston Waterfront',
#  'neighbourhood_cleansed_South End',
#  'neighbourhood_cleansed_West End',
#  'neighbourhood_cleansed_West Roxbury',
#  'property_type_Aparthotel',
#  'property_type_Apartment',
#  'property_type_Barn',
#  'property_type_Bed and breakfast',
#  'property_type_Boat',
#  'property_type_Boutique hotel',
#  'property_type_Bungalow',
#  'property_type_Camper/RV',
#  'property_type_Chalet',
#  'property_type_Condominium',
#  'property_type_Guest suite',
#  'property_type_Guesthouse',
#  'property_type_Hotel',
#  'property_type_House',
#  'property_type_Loft',
#  'property_type_Other',
#  'property_type_Resort',
#  'property_type_Serviced apartment',
#  'property_type_Tiny house',
#  'property_type_Townhouse',
#  'property_type_Villa',
#  'room_type_Entire home/apt',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'cancellation_policy_flexible',
#  'cancellation_policy_moderate',
#  'cancellation_policy_strict',
#  'cancellation_policy_strict_14_with_grace_period',
#  'cancellation_policy_super_strict_30',
#  'cancellation_policy_super_strict_60',
#  '24-hourcheck-in',
#  'Accessible-heightbed',
#  'Accessible-heighttoilet',
#  'Airconditioning',
#  'BBQgrill',
#  'Babybath',
#  'Babymonitor',
#  'Babysitterrecommendations',
#  'Bathtub',
#  'Bathtubwithbathchair',
#  'Beachessentials',
#  'Beachfront',
#  'Bedlinens',
#  'Breakfast',
#  'Buildingstaff',
#  'Buzzer/wirelessintercom',
#  'CableTV',
#  'Carbonmonoxidedetector',
#  'Cat(s)',
#  'Changingtable',
#  'Children’sbooksandtoys',
#  'Children’sdinnerware',
#  'Cleaningbeforecheckout',
#  'Coffeemaker',
#  'Cookingbasics',
#  'Crib',
#  'Disabledparkingspot',
#  'Dishesandsilverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Dryer',
#  'EVcharger',
#  'Electricprofilingbed',
#  'Elevator',
#  'Essentials',
#  'Ethernetconnection',
#  'Extrapillowsandblankets',
#  'Family/kidfriendly',
#  'Fireextinguisher',
#  'Fireplaceguards',
#  'Firmmattress',
#  'Firstaidkit',
#  'Fixedgrabbarsforshower',
#  'Fixedgrabbarsfortoilet',
#  'Flatpathtofrontdoor',
#  'Freeparkingonpremises',
#  'Freestreetparking',
#  'Gameconsole',
#  'Gardenorbackyard',
#  'Gym',
#  'Hairdryer',
#  'Handheldshowerhead',
#  'Hangers',
#  'Heating',
#  'Highchair',
#  'Hostgreetsyou',
#  'Hottub',
#  'Hotwater',
#  'Hotwaterkettle',
#  'Indoorfireplace',
#  'Internet',
#  'Iron',
#  'Keypad',
#  'Kitchen',
#  'Lakeaccess',
#  'Laptopfriendlyworkspace',
#  'Lockbox',
#  'Lockonbedroomdoor',
#  'Longtermstaysallowed',
#  'Luggagedropoffallowed',
#  'Microwave',
#  'Other',
#  'Otherpet(s)',
#  'Outletcovers',
#  'Oven',
#  'Pack’nPlay/travelcrib',
#  'Paidparkingoffpremises',
#  'Paidparkingonpremises',
#  'Patioorbalcony',
#  'Petsallowed',
#  'Petsliveonthisproperty',
#  'Pocketwifi',
#  'Pool',
#  'Privatebathroom',
#  'Privateentrance',
#  'Privatelivingroom',
#  'Refrigerator',
#  'Roll-inshower',
#  'Room-darkeningshades',
#  'Safetycard',
#  'Selfcheck-in',
#  'Shampoo',
#  'Showerchair',
#  'Singlelevelhome',
#  'Ski-in/Ski-out',
#  'Smartlock',
#  'Smokedetector',
#  'Smokingallowed',
#  'Stairgates',
#  'Step-freeaccess',
#  'Stove',
#  'Suitableforevents',
#  'TV',
#  'Tablecornerguards',
#  'Washer',
#  'Washer/Dryer',
#  'Waterfront',
#  'Well-litpathtoentrance',
#  'Wheelchairaccessible',
#  'Wideclearancetobed',
#  'Wideclearancetoshower',
#  'Widedoorway',
#  'Wideentryway',
#  'Widehallwayclearance',
#  'Wifi',
#  'Windowguards',
#  'toilet',
#  'translationmissing:en.hosting_amenity_49',
#  'translationmissing:en.hosting_amenity_50']

# %%
#splitting into explanatory and response variables
X = df_model.drop(['price', 'id', 'cleaning_fee'], axis=1)
X = sm.add_constant(X)
y = df_model['price']

#splitting the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, 
                                                    random_state = 42)

#showing the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 4725 samples.
# Testing set has 1182 samples.
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning:
#
# Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.

# %% [markdown]
# ---
# # <center>STAGE FOUR</center>
# ---

# %% [markdown]
# ## 5. Evaluation
#
# *Source of using statsmodels(sm): Seabold, Skipper, and Josef Perktold. “Statsmodels: Econometric and statistical modeling with python.” Proceedings of the 9th Python in Science Conference. 2010.*

# %%
#predicting and obtaining a summary of the Ordinary least squares method
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

#printing out the statistics
print(type(model))
print(model.summary())
# Out:
# <class 'statsmodels.regression.linear_model.RegressionResultsWrapper'>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.609
# Method:                 Least Squares   F-statistic:                     52.86
# Date:                Thu, 09 May 2019   Prob (F-statistic):               0.00
# Time:                        22:51:02   Log-Likelihood:                -32648.
# No. Observations:                5907   AIC:                         6.565e+04
# Df Residuals:                    5729   BIC:                         6.684e+04
# Df Model:                         177
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              41.1200      7.639      5.383      0.000      26.145      56.095
# host_is_superhost                                   8.1308      2.291      3.549      0.000       3.640      12.622
# accommodates                                       10.2016      0.981     10.397      0.000       8.278      12.125
# bathrooms                                          18.7747      2.108      8.905      0.000      14.642      22.908
# bedrooms                                           17.7166      1.559     11.364      0.000      14.660      20.773
# beds                                               -1.6729      1.449     -1.155      0.248      -4.513       1.167
# number_of_reviews                                  -0.1059      0.018     -5.958      0.000      -0.141      -0.071
# instant_bookable                                   -1.0441      1.894     -0.551      0.582      -4.758       2.669
# neighbourhood_cleansed_Allston                    -23.8184      3.901     -6.106      0.000     -31.465     -16.172
# neighbourhood_cleansed_Back Bay                    57.0810      3.624     15.750      0.000      49.976      64.186
# neighbourhood_cleansed_Bay Village                 22.4419     10.226      2.195      0.028       2.394      42.489
# neighbourhood_cleansed_Beacon Hill                 26.7110      4.373      6.108      0.000      18.137      35.285
# neighbourhood_cleansed_Brighton                   -24.8386      3.750     -6.623      0.000     -32.191     -17.486
# neighbourhood_cleansed_Charlestown                 23.2273      5.378      4.319      0.000      12.684      33.771
# neighbourhood_cleansed_Chinatown                   31.6667      5.749      5.508      0.000      20.397      42.937
# neighbourhood_cleansed_Dorchester                 -26.9617      3.509     -7.684      0.000     -33.841     -20.083
# neighbourhood_cleansed_Downtown                    31.4929      3.772      8.349      0.000      24.098      38.888
# neighbourhood_cleansed_East Boston                -19.5334      3.949     -4.946      0.000     -27.275     -11.791
# neighbourhood_cleansed_Fenway                      16.2577      3.677      4.421      0.000       9.049      23.467
# neighbourhood_cleansed_Hyde Park                  -44.8124      8.293     -5.403      0.000     -61.070     -28.555
# neighbourhood_cleansed_Jamaica Plain              -12.6315      3.384     -3.733      0.000     -19.265      -5.998
# neighbourhood_cleansed_Leather District            51.0500     24.948      2.046      0.041       2.143      99.957
# neighbourhood_cleansed_Longwood Medical Area      -16.4789     18.183     -0.906      0.365     -52.124      19.167
# neighbourhood_cleansed_Mattapan                   -44.7050      7.549     -5.922      0.000     -59.504     -29.906
# neighbourhood_cleansed_Mission Hill                -5.7462      4.824     -1.191      0.234     -15.202       3.710
# neighbourhood_cleansed_North End                    7.7663      4.562      1.702      0.089      -1.177      16.710
# neighbourhood_cleansed_Roslindale                 -40.1441      6.083     -6.600      0.000     -52.069     -28.220
# neighbourhood_cleansed_Roxbury                    -14.5195      4.043     -3.591      0.000     -22.445      -6.594
# neighbourhood_cleansed_South Boston                20.6289      3.880      5.317      0.000      13.022      28.235
# neighbourhood_cleansed_South Boston Waterfront     35.0167      7.808      4.485      0.000      19.711      50.322
# neighbourhood_cleansed_South End                   28.4684      3.553      8.012      0.000      21.502      35.434
# neighbourhood_cleansed_West End                     8.8566      6.084      1.456      0.146      -3.071      20.784
# neighbourhood_cleansed_West Roxbury               -45.3555      7.856     -5.773      0.000     -60.756     -29.955
# property_type_Aparthotel                           29.1468     59.760      0.488      0.626     -88.005     146.298
# property_type_Apartment                           -28.5259      7.233     -3.944      0.000     -42.706     -14.346
# property_type_Barn                                 63.4438     59.541      1.066      0.287     -53.279     180.167
# property_type_Bed and breakfast                    12.0850     11.825      1.022      0.307     -11.096      35.266
# property_type_Boat                                 14.2609     18.926      0.754      0.451     -22.842      51.363
# property_type_Boutique hotel                       -0.6164     16.213     -0.038      0.970     -32.399      31.166
# property_type_Bungalow                             72.9987     32.696      2.233      0.026       8.903     137.095
# property_type_Camper/RV                           -23.0698     42.975     -0.537      0.591    -107.317      61.177
# property_type_Chalet                              -37.4532     59.707     -0.627      0.531    -154.502      79.596
# property_type_Condominium                         -32.3600      7.651     -4.229      0.000     -47.359     -17.361
# property_type_Guest suite                         -38.7429     10.307     -3.759      0.000     -58.948     -18.538
# property_type_Guesthouse                          -33.4160     21.135     -1.581      0.114     -74.849       8.017
# property_type_Hotel                                20.1201     27.990      0.719      0.472     -34.751      74.991
# property_type_House                               -25.1252      7.501     -3.349      0.001     -39.831     -10.419
# property_type_Loft                                -22.6540     11.364     -1.994      0.046     -44.931      -0.377
# property_type_Other                               -11.9901     11.415     -1.050      0.294     -34.367      10.387
# property_type_Resort                               -4.9160     42.736     -0.115      0.908     -88.694      78.862
# property_type_Serviced apartment                   47.7269      8.947      5.335      0.000      30.188      65.266
# property_type_Tiny house                           29.5680     59.628      0.496      0.620     -87.325     146.461
# property_type_Townhouse                           -13.5713      9.028     -1.503      0.133     -31.270       4.128
# property_type_Villa                                24.2106     23.721      1.021      0.307     -22.292      70.713
# room_type_Entire home/apt                          57.8253      3.695     15.649      0.000      50.581      65.069
# room_type_Private room                              5.3542      3.380      1.584      0.113      -1.272      11.980
# room_type_Shared room                             -22.0595      6.287     -3.509      0.000     -34.385      -9.734
# cancellation_policy_flexible                       -4.2094      4.318     -0.975      0.330     -12.674       4.255
# cancellation_policy_moderate                       -4.8046      4.360     -1.102      0.271     -13.352       3.743
# cancellation_policy_strict                         64.5585      9.012      7.164      0.000      46.893      82.225
# cancellation_policy_strict_14_with_grace_period     0.3689      4.181      0.088      0.930      -7.827       8.564
# cancellation_policy_super_strict_30               -24.6573      8.217     -3.001      0.003     -40.765      -8.549
# cancellation_policy_super_strict_60                 9.8638     19.287      0.511      0.609     -27.945      47.673
# 24-hourcheck-in                                     0.5160      2.876      0.179      0.858      -5.122       6.154
# Accessible-heightbed                                5.7915      7.966      0.727      0.467      -9.825      21.408
# Accessible-heighttoilet                            -1.8596      8.101     -0.230      0.818     -17.741      14.022
# Airconditioning                                    11.2372      2.514      4.469      0.000       6.308      16.166
# BBQgrill                                            1.1633      4.534      0.257      0.798      -7.725      10.051
# Babybath                                          -25.7839      9.403     -2.742      0.006     -44.218      -7.350
# Babymonitor                                         0.7851     17.108      0.046      0.963     -32.754      34.324
# Babysitterrecommendations                          -4.6887     10.278     -0.456      0.648     -24.837      15.460
# Bathtub                                            19.6087      3.090      6.346      0.000      13.551      25.666
# Bathtubwithbathchair                              -32.8297     17.563     -1.869      0.062     -67.259       1.600
# Beachessentials                                    12.6406     10.917      1.158      0.247      -8.761      34.042
# Beachfront                                         26.1644      9.577      2.732      0.006       7.390      44.939
# Bedlinens                                         -11.8756      3.167     -3.749      0.000     -18.085      -5.666
# Breakfast                                           4.0762      3.119      1.307      0.191      -2.038      10.190
# Buildingstaff                                     -15.1799     22.708     -0.668      0.504     -59.695      29.335
# Buzzer/wirelessintercom                             4.1456      3.194      1.298      0.194      -2.116      10.407
# CableTV                                             3.2588      2.161      1.508      0.132      -0.979       7.496
# Carbonmonoxidedetector                             -3.3721      2.955     -1.141      0.254      -9.166       2.422
# Cat(s)                                            -13.3417      7.605     -1.754      0.079     -28.250       1.567
# Changingtable                                       6.7012     14.603      0.459      0.646     -21.926      35.329
# Children’sbooksandtoys                             15.0699      6.315      2.386      0.017       2.691      27.449
# Children’sdinnerware                               -8.2546      8.228     -1.003      0.316     -24.385       7.876
# Cleaningbeforecheckout                             -3.9444      5.907     -0.668      0.504     -15.524       7.635
# Coffeemaker                                        -1.9149      3.751     -0.510      0.610      -9.269       5.439
# Cookingbasics                                      -3.3220      4.222     -0.787      0.431     -11.599       4.955
# Crib                                               12.0633      7.577      1.592      0.111      -2.790      26.917
# Disabledparkingspot                                -8.9960      9.265     -0.971      0.332     -27.158       9.166
# Dishesandsilverware                               -23.0995      4.767     -4.846      0.000     -32.445     -13.754
# Dishwasher                                         11.6200      3.300      3.521      0.000       5.150      18.090
# Dog(s)                                              2.7799      7.236      0.384      0.701     -11.405      16.965
# Doorman                                            -8.9855      5.718     -1.572      0.116     -20.194       2.223
# Dryer                                              -2.5699      7.606     -0.338      0.735     -17.480      12.340
# EVcharger                                          23.0132     20.805      1.106      0.269     -17.772      63.798
# Electricprofilingbed                               80.5021     34.394      2.341      0.019      13.076     147.928
# Elevator                                            9.5402      2.920      3.267      0.001       3.816      15.264
# Essentials                                          8.3976      4.485      1.872      0.061      -0.395      17.190
# Ethernetconnection                                 15.5842      4.188      3.721      0.000       7.374      23.794
# Extrapillowsandblankets                             5.7939      3.079      1.882      0.060      -0.242      11.830
# Family/kidfriendly                                  4.7869      2.189      2.187      0.029       0.496       9.078
# Fireextinguisher                                    3.0485      2.026      1.505      0.132      -0.924       7.021
# Fireplaceguards                                    -6.2254     11.981     -0.520      0.603     -29.712      17.261
# Firmmattress                                       17.5100     29.135      0.601      0.548     -39.606      74.626
# Firstaidkit                                        -4.2692      2.254     -1.894      0.058      -8.688       0.150
# Fixedgrabbarsforshower                             -8.1380     13.821     -0.589      0.556     -35.232      18.956
# Fixedgrabbarsfortoilet                             56.2564     34.475      1.632      0.103     -11.328     123.840
# Flatpathtofrontdoor                                -1.7477      7.139     -0.245      0.807     -15.743      12.248
# Freeparkingonpremises                              -1.2746      2.620     -0.486      0.627      -6.412       3.862
# Freestreetparking                                  -7.0391      2.578     -2.730      0.006     -12.094      -1.985
# Gameconsole                                        -5.1697     10.823     -0.478      0.633     -26.387      16.047
# Gardenorbackyard                                    4.0670      3.795      1.072      0.284      -3.374      11.508
# Gym                                                12.7989      3.582      3.573      0.000       5.777      19.820
# Hairdryer                                          -3.2117      2.749     -1.168      0.243      -8.601       2.178
# Handheldshowerhead                                 -0.1874      7.387     -0.025      0.980     -14.670      14.295
# Hangers                                            -5.2090      2.955     -1.763      0.078     -11.001       0.583
# Heating                                             3.2545      5.104      0.638      0.524      -6.750      13.259
# Highchair                                          -0.7952      6.759     -0.118      0.906     -14.046      12.456
# Hostgreetsyou                                       0.0907      3.593      0.025      0.980      -6.953       7.135
# Hottub                                             12.1866      5.873      2.075      0.038       0.673      23.701
# Hotwater                                            2.1784      2.669      0.816      0.414      -3.053       7.410
# Hotwaterkettle                                    -20.4160     15.850     -1.288      0.198     -51.488      10.656
# Indoorfireplace                                    10.9353      3.086      3.543      0.000       4.885      16.985
# Internet                                           -1.7201      2.321     -0.741      0.459      -6.271       2.831
# Iron                                                4.5790      2.753      1.663      0.096      -0.818       9.976
# Keypad                                            -12.2660     22.229     -0.552      0.581     -55.843      31.311
# Kitchen                                           -12.1642      3.671     -3.313      0.001     -19.361      -4.967
# Lakeaccess                                        -12.2757     15.255     -0.805      0.421     -42.180      17.629
# Laptopfriendlyworkspace                            -2.9099      2.327     -1.250      0.211      -7.472       1.652
# Lockbox                                           -14.5483     22.269     -0.653      0.514     -58.203      29.107
# Lockonbedroomdoor                                  -5.2428      2.180     -2.405      0.016      -9.517      -0.969
# Longtermstaysallowed                                2.9800      2.468      1.207      0.227      -1.859       7.819
# Luggagedropoffallowed                               2.5273      2.678      0.944      0.345      -2.722       7.776
# Microwave                                          12.2989      5.113      2.406      0.016       2.276      22.322
# Other                                               5.6924      3.799      1.498      0.134      -1.755      13.140
# Otherpet(s)                                       -24.5313     17.898     -1.371      0.171     -59.617      10.555
# Outletcovers                                        6.3317     11.103      0.570      0.569     -15.434      28.098
# Oven                                               -8.0282      5.427     -1.479      0.139     -18.668       2.611
# Pack’nPlay/travelcrib                             -14.0503      4.016     -3.498      0.000     -21.924      -6.177
# Paidparkingoffpremises                              1.5813      2.900      0.545      0.586      -4.104       7.266
# Paidparkingonpremises                             -13.3467      3.475     -3.841      0.000     -20.159      -6.535
# Patioorbalcony                                     -3.3565      3.345     -1.003      0.316      -9.915       3.202
# Petsallowed                                         6.0075      2.700      2.225      0.026       0.715      11.300
# Petsliveonthisproperty                             10.8779      6.492      1.676      0.094      -1.849      23.605
# Pocketwifi                                        -16.2228      7.577     -2.141      0.032     -31.077      -1.369
# Pool                                               14.1840      4.221      3.360      0.001       5.908      22.460
# Privatebathroom                                   -32.0464     37.809     -0.848      0.397    -106.167      42.074
# Privateentrance                                     4.1899      2.474      1.694      0.090      -0.660       9.039
# Privatelivingroom                                  13.8947      2.786      4.987      0.000       8.432      19.357
# Refrigerator                                       -1.6129      6.016     -0.268      0.789     -13.407      10.181
# Roll-inshower                                     -17.8744     18.238     -0.980      0.327     -53.628      17.879
# Room-darkeningshades                              -28.6885      5.157     -5.563      0.000     -38.799     -18.578
# Safetycard                                         -0.5672      3.049     -0.186      0.852      -6.544       5.409
# Selfcheck-in                                        8.6903     22.292      0.390      0.697     -35.011      52.392
# Shampoo                                             5.4592      2.578      2.118      0.034       0.406      10.513
# Showerchair                                       -48.7828     24.056     -2.028      0.043     -95.942      -1.623
# Singlelevelhome                                    -6.6083      5.401     -1.224      0.221     -17.196       3.980
# Ski-in/Ski-out                                    -43.0620     11.690     -3.684      0.000     -65.978     -20.146
# Smartlock                                         -17.0710     22.284     -0.766      0.444     -60.757      26.615
# Smokedetector                                       0.5059      4.585      0.110      0.912      -8.483       9.495
# Smokingallowed                                     -8.3292      6.049     -1.377      0.169     -20.188       3.530
# Stairgates                                         22.4911     10.195      2.206      0.027       2.505      42.477
# Step-freeaccess                                   -12.5702      5.572     -2.256      0.024     -23.493      -1.648
# Stove                                              12.4910      6.099      2.048      0.041       0.534      24.448
# Suitableforevents                                  -1.6986      5.445     -0.312      0.755     -12.372       8.975
# TV                                                 10.6421      2.484      4.285      0.000       5.773      15.511
# Tablecornerguards                                 -28.6059     34.616     -0.826      0.409     -96.466      39.254
# Washer                                              7.6989      7.661      1.005      0.315      -7.320      22.718
# Washer/Dryer                                       56.7747     44.624      1.272      0.203     -30.705     144.254
# Waterfront                                         -6.3847     10.310     -0.619      0.536     -26.596      13.827
# Well-litpathtoentrance                             12.2470      4.894      2.503      0.012       2.653      21.841
# Wheelchairaccessible                                5.9885      6.515      0.919      0.358      -6.783      18.760
# Wideclearancetobed                                 -2.0394      7.686     -0.265      0.791     -17.108      13.029
# Wideclearancetoshower                              -4.8623      4.674     -1.040      0.298     -14.024       4.300
# Widedoorway                                        -8.2873      7.366     -1.125      0.261     -22.727       6.153
# Wideentryway                                        6.6891      8.063      0.830      0.407      -9.118      22.497
# Widehallwayclearance                                8.5779      6.718      1.277      0.202      -4.591      21.747
# Wifi                                                2.6391      5.914      0.446      0.655      -8.955      14.233
# Windowguards                                       13.0799     11.363      1.151      0.250      -9.197      35.356
# toilet                                             -4.8623      4.674     -1.040      0.298     -14.024       4.300
# translationmissing:en.hosting_amenity_49            1.5886      4.669      0.340      0.734      -7.565      10.742
# translationmissing:en.hosting_amenity_50            1.4295      4.259      0.336      0.737      -6.920       9.779
# ==============================================================================
# Omnibus:                     1227.332   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3766.293
# Skew:                           1.064   Prob(JB):                         0.00
# Kurtosis:                       6.282   Cond. No.                     1.73e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.58e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Based on the Regression Results, the Adjusted R<sup>2</sup> (adjusted R<sup>2</sup> was chosen instead of R<sup>2</sup> because it accounts for the number of features) states that the listed features can explain 61% of the variability in the price for Boston Airbnb. Next, we will see which features have more weight and impact than other features do and then determine whether there is a significant relationship between the features in the model. If the p-value of each of the feature is less than 0.05, we conclude that there is sufficient evidence to say that we are 95% confident that there is a significant linear relationship between the price and the feature.

# %% [markdown]
# ---
# ### <font color=blue> Q8. What are the features that infleunce the price in Boston airbinb? And, can we predict the price of new listings based on a predictive model?

# %%
#understanding the most influential coefficients in the model
np.abs(model.params).sort_values(ascending=False)
# Out:
# Electricprofilingbed                               80.502081
# property_type_Bungalow                             72.998709
# cancellation_policy_strict                         64.558547
# property_type_Barn                                 63.443751
# room_type_Entire home/apt                          57.825315
# neighbourhood_cleansed_Back Bay                    57.080997
# Washer/Dryer                                       56.774705
# Fixedgrabbarsfortoilet                             56.256382
# neighbourhood_cleansed_Leather District            51.050006
# Showerchair                                        48.782778
# property_type_Serviced apartment                   47.726852
# neighbourhood_cleansed_West Roxbury                45.355507
# neighbourhood_cleansed_Hyde Park                   44.812446
# neighbourhood_cleansed_Mattapan                    44.705022
# Ski-in/Ski-out                                     43.061954
# const                                              41.120013
# neighbourhood_cleansed_Roslindale                  40.144102
# property_type_Guest suite                          38.742895
# property_type_Chalet                               37.453194
# neighbourhood_cleansed_South Boston Waterfront     35.016654
# property_type_Guesthouse                           33.415968
# Bathtubwithbathchair                               32.829705
# property_type_Condominium                          32.360021
# Privatebathroom                                    32.046431
# neighbourhood_cleansed_Chinatown                   31.666661
# neighbourhood_cleansed_Downtown                    31.492873
# property_type_Tiny house                           29.567973
# property_type_Aparthotel                           29.146802
# Room-darkeningshades                               28.688498
# Tablecornerguards                                  28.605936
#                                                      ...
# Laptopfriendlyworkspace                             2.909901
# Dog(s)                                              2.779931
# Wifi                                                2.639071
# Dryer                                               2.569853
# Luggagedropoffallowed                               2.527296
# Hotwater                                            2.178412
# Wideclearancetobed                                  2.039413
# Coffeemaker                                         1.914911
# Accessible-heighttoilet                             1.859616
# Flatpathtofrontdoor                                 1.747731
# Internet                                            1.720090
# Suitableforevents                                   1.698644
# beds                                                1.672877
# Refrigerator                                        1.612933
# translationmissing:en.hosting_amenity_49            1.588552
# Paidparkingoffpremises                              1.581336
# translationmissing:en.hosting_amenity_50            1.429468
# Freeparkingonpremises                               1.274630
# BBQgrill                                            1.163336
# instant_bookable                                    1.044147
# Highchair                                           0.795203
# Babymonitor                                         0.785142
# property_type_Boutique hotel                        0.616442
# Safetycard                                          0.567184
# 24-hourcheck-in                                     0.515967
# Smokedetector                                       0.505947
# cancellation_policy_strict_14_with_grace_period     0.368900
# Handheldshowerhead                                  0.187420
# number_of_reviews                                   0.105865
# Hostgreetsyou                                       0.090662
# Length: 183, dtype: float64

# %% [markdown]
# Based on the previous investigation, we can say that these features have more impact on predicting the price for Boston Airbnb listings by either increasing or decreasing the price:
#
# 1. With respect to amenities:
#
#             - Electric Profiling Bed
#             - Stair gates
#             - Washer/Dryer
#             - Hot Water Kettle
#             - Fixed Grab Bars For Toilet
#             - Private bathroom
#             - Room-darkening shades
#
# 2. With respect to property type:
#
#             - Bungalow
#             - Serviced apartment
#             - Tiny house
#             - Hotel
#             - House
#
# 3. With respect to the neighborhood:
#
#             - Back Bay
#             - Leather District
#             - South Boston Waterfront
#             - Chinatown
#             - Downtown
#             - Mattapan
#             - Hyde Park
#
# 4. With respect to other rules and features:
#
#             - cancellation policy: strict
#             - room type: Entire home/apt

# %%
#looking at a summary of the coefficients
np.abs(model.params).describe()
# Out:
# count    183.000000
# mean      15.719676
# std       15.629477
# min        0.090662
# 25%        4.633837
# 50%       11.619952
# 75%       22.833570
# max       80.502081
# dtype: float64

# %%
#listing only the 25% most influential coefficients in the model
coeffs = model.params[np.abs(model.params) >= 20]
print(coeffs.sort_values(ascending=False))
# Out:
# Electricprofilingbed                              80.502081
# property_type_Bungalow                            72.998709
# cancellation_policy_strict                        64.558547
# property_type_Barn                                63.443751
# room_type_Entire home/apt                         57.825315
# neighbourhood_cleansed_Back Bay                   57.080997
# Washer/Dryer                                      56.774705
# Fixedgrabbarsfortoilet                            56.256382
# neighbourhood_cleansed_Leather District           51.050006
# property_type_Serviced apartment                  47.726852
# const                                             41.120013
# neighbourhood_cleansed_South Boston Waterfront    35.016654
# neighbourhood_cleansed_Chinatown                  31.666661
# neighbourhood_cleansed_Downtown                   31.492873
# property_type_Tiny house                          29.567973
# property_type_Aparthotel                          29.146802
# neighbourhood_cleansed_South End                  28.468382
# neighbourhood_cleansed_Beacon Hill                26.711018
# Beachfront                                        26.164439
# property_type_Villa                               24.210605
# neighbourhood_cleansed_Charlestown                23.227346
# EVcharger                                         23.013188
# Stairgates                                        22.491148
# neighbourhood_cleansed_Bay Village                22.441854
# neighbourhood_cleansed_South Boston               20.628887
# property_type_Hotel                               20.120097
# Hotwaterkettle                                   -20.415961
# room_type_Shared room                            -22.059452
# property_type_Loft                               -22.653953
# property_type_Camper/RV                          -23.069791
# Dishesandsilverware                              -23.099468
# neighbourhood_cleansed_Allston                   -23.818354
# Otherpet(s)                                      -24.531327
# cancellation_policy_super_strict_30              -24.657292
# neighbourhood_cleansed_Brighton                  -24.838649
# property_type_House                              -25.125219
# Babybath                                         -25.783885
# neighbourhood_cleansed_Dorchester                -26.961677
# property_type_Apartment                          -28.525897
# Tablecornerguards                                -28.605936
# Room-darkeningshades                             -28.688498
# Privatebathroom                                  -32.046431
# property_type_Condominium                        -32.360021
# Bathtubwithbathchair                             -32.829705
# property_type_Guesthouse                         -33.415968
# property_type_Chalet                             -37.453194
# property_type_Guest suite                        -38.742895
# neighbourhood_cleansed_Roslindale                -40.144102
# Ski-in/Ski-out                                   -43.061954
# neighbourhood_cleansed_Mattapan                  -44.705022
# neighbourhood_cleansed_Hyde Park                 -44.812446
# neighbourhood_cleansed_West Roxbury              -45.355507
# Showerchair                                      -48.782778
# dtype: float64

# %%
features_coeffs = coeffs.sort_values(ascending=True)


trace1 = go.Bar(
    y=features_coeffs.index,
    x=features_coeffs,
    name='Most Influential Features',
    orientation = 'h',
    marker = dict(
        color = 'rgb(158,202,225)',
        line = dict(
            color = 'rgb(8,48,107)',
            width = 1.5),
        opacity=0.6
    ))

data = [trace1]
 
layout = go.Layout(
    title = "Most Influential Features",
    xaxis=dict(
        title='Coefficients',
        autorange=True),
    yaxis=dict(automargin=True,
               autorange=True))

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Most Influential Features')
# Out:
# /Users/Saleh/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~salitr/506.embed" height="525px" width="100%"></iframe>

# %%
#listing the features that are signficant at 95% confendance level, and has p-values less than 0.005
pvalues = model.pvalues[model.pvalues < 0.05]
pvalues
# Out:
# const                                             7.621847e-08
# host_is_superhost                                 3.897856e-04
# accommodates                                      4.282992e-25
# bathrooms                                         7.039712e-19
# bedrooms                                          1.313636e-29
# number_of_reviews                                 2.699818e-09
# neighbourhood_cleansed_Allston                    1.087438e-09
# neighbourhood_cleansed_Back Bay                   9.484528e-55
# neighbourhood_cleansed_Bay Village                2.823893e-02
# neighbourhood_cleansed_Beacon Hill                1.078504e-09
# neighbourhood_cleansed_Brighton                   3.843618e-11
# neighbourhood_cleansed_Charlestown                1.595068e-05
# neighbourhood_cleansed_Chinatown                  3.779635e-08
# neighbourhood_cleansed_Dorchester                 1.809144e-14
# neighbourhood_cleansed_Downtown                   8.553095e-17
# neighbourhood_cleansed_East Boston                7.784663e-07
# neighbourhood_cleansed_Fenway                     1.000812e-05
# neighbourhood_cleansed_Hyde Park                  6.799441e-08
# neighbourhood_cleansed_Jamaica Plain              1.909002e-04
# neighbourhood_cleansed_Leather District           4.077632e-02
# neighbourhood_cleansed_Mattapan                   3.365571e-09
# neighbourhood_cleansed_Roslindale                 4.492223e-11
# neighbourhood_cleansed_Roxbury                    3.319267e-04
# neighbourhood_cleansed_South Boston               1.097595e-07
# neighbourhood_cleansed_South Boston Waterfront    7.434838e-06
# neighbourhood_cleansed_South End                  1.360640e-15
# neighbourhood_cleansed_West Roxbury               8.177210e-09
# property_type_Apartment                           8.120351e-05
# property_type_Bungalow                            2.560919e-02
# property_type_Condominium                         2.379940e-05
#                                                       ...
# Bedlinens                                         1.791364e-04
# Children’sbooksandtoys                            1.704440e-02
# Dishesandsilverware                               1.295579e-06
# Dishwasher                                        4.336266e-04
# Electricprofilingbed                              1.928861e-02
# Elevator                                          1.092085e-03
# Ethernetconnection                                2.002927e-04
# Family/kidfriendly                                2.879104e-02
# Freestreetparking                                 6.349476e-03
# Gym                                               3.552727e-04
# Hottub                                            3.804150e-02
# Indoorfireplace                                   3.983112e-04
# Kitchen                                           9.272693e-04
# Lockonbedroomdoor                                 1.621016e-02
# Microwave                                         1.618103e-02
# Pack’nPlay/travelcrib                             4.717461e-04
# Paidparkingonpremises                             1.238888e-04
# Petsallowed                                       2.611645e-02
# Pocketwifi                                        3.231511e-02
# Pool                                              7.845246e-04
# Privatelivingroom                                 6.320286e-07
# Room-darkeningshades                              2.776986e-08
# Shampoo                                           3.424097e-02
# Showerchair                                       4.262085e-02
# Ski-in/Ski-out                                    2.319411e-04
# Stairgates                                        2.741625e-02
# Step-freeaccess                                   2.410292e-02
# Stove                                             4.061116e-02
# TV                                                1.858946e-05
# Well-litpathtoentrance                            1.235845e-02
# Length: 72, dtype: float64

# %%
# !!jupyter nbconvert *.ipynb
# Out:
# ['[NbConvertApp] Converting notebook boston_airbnb_analysis.ipynb to html',
#  '[NbConvertApp] Writing 660642 bytes to boston_airbnb_analysis.html']
